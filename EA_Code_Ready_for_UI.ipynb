# %% [markdown]
# # Imports Section

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
from itertools import combinations

# %%
PARAMS = {
    "pop_size": 30,
    "num_sensors": 10,
    "generations": 30,
    "mutation_start": 0.4,
    "mutation_end": 0.05,
    "crossover_start": 0.9,
    "crossover_end": 0.5,
    "radius": 5
}

# %% [markdown]
# # Loading Dataset

# %%
df = pd.read_csv("metr_la_reduced.csv")
df.head()
# Out:
#              timestamp  sensor_id      speed  traffic_level  index  latitude  \
# 0  2012-05-28 17:40:00     717510   0.000000              2    180  34.17128
# 1  2012-04-10 05:50:00     764766  65.222222              0     68  34.13338
# 2  2012-05-09 20:00:00     767350  65.444444              0     88  34.18011
# 3  2012-04-15 20:30:00     765176  68.375000              0     74  34.13286
# 4  2012-06-12 11:10:00     773013  55.111111              0     30  34.08374
#
#    longitude
# 0 -118.51976
# 1 -118.35350
# 2 -118.47045
# 3 -118.35135
# 4 -118.22076

# %% [markdown]
# ---
#
#
# #**1] Problem Modelling & Dataset Processing**
#
#
# ---

# %% [markdown]
# # Grid Design

# %%
grid_size = 50

# 1) Boundary extraction
min_lat, max_lat = df["latitude"].min(), df["latitude"].max()
min_lon, max_lon = df["longitude"].min(), df["longitude"].max()

df.dropna(subset=['latitude', 'longitude'], inplace=True)

# 2) Convert Lat → X
df["x"] = np.floor(
    (df["latitude"] - min_lat) /
    (max_lat - min_lat + 1e-9) * grid_size
).astype(int)

# 3) Convert Lon → Y
df["y"] = np.floor(
    (df["longitude"] - min_lon) /
    (max_lon - min_lon + 1e-9) * grid_size
).astype(int)

# 4) Prevent out-of-bounds movement within the grid (IMPORTANT)
df["x"] = df["x"].clip(0, grid_size - 1) # X range: 0 → 49
df["y"] = df["y"].clip(0, grid_size - 1) # Y range: 0 → 49

# %%
# 5) Result verification
print("Grid created")
print(df[["latitude", "longitude", "x", "y"]].head())
# Out:
# Grid created
#    latitude  longitude   x   y
# 0  34.17128 -118.51976  35   2
# 1  34.13338 -118.35350  25  25
# 2  34.18011 -118.47045  38   9
# 3  34.13286 -118.35135  25  26
# 4  34.08374 -118.22076  11  44

# %% [markdown]
# # Sensor Distribution Map

# %%
#visualization
plt.figure(figsize=(7,7))

plt.scatter(
    df["x"],
    df["y"],
    s=1,
    alpha=0.5
)

plt.title("Sensor Distribution on Grid")
plt.xlabel("X Grid")
plt.ylabel("Y Grid")
plt.grid(True)

plt.show()

# %% [markdown]
# # Heat Map

# %%
#Heatmap (Traffic Intensity)
heatmap = df.groupby(["x", "y"])["traffic_level"].mean().unstack()
density = df.groupby(["x", "y"]).size().unstack().fillna(0)

high_traffic = df[df["traffic_level"] == 2]
heat_high = high_traffic.groupby(["x", "y"]).size().unstack()

plt.figure(figsize=(10,8))

# heatmap values
data = heatmap.fillna(0).values

plt.imshow(
    data,
    origin="lower",
    cmap="YlGnBu",
)

plt.colorbar(label="Traffic Level")

plt.title("Traffic Heatmap")
plt.xlabel("X Grid")
plt.ylabel("Y Grid")


for i in range(data.shape[0]):
    for j in range(data.shape[1]):
        if data[i, j] != 0:
            plt.text(
                j, i,
                f"{data[i, j]:.0f}",
                ha='center',
                va='center',
                fontsize=6,
                color='black'
            )

plt.show()

# %% [markdown]
# # Sensor Density Map

# %%
plt.figure(figsize=(8,6))

plt.imshow(
    density,
    origin="lower",
    cmap="Blues",
    interpolation="nearest"
)

plt.colorbar(label="Sensor Density")
plt.title("Sensor Density Map")
plt.xlabel("X")
plt.ylabel("Y")

plt.show()

# %% [markdown]
# # High Traffic Only Map

# %%
plt.figure(figsize=(8,6))

plt.imshow(
    heat_high,
    origin="lower",
    cmap="Reds",
    interpolation="nearest"
)

plt.colorbar(label="High Traffic Count")
plt.title("High Traffic Hotspots")
plt.xlabel("X")
plt.ylabel("Y")

plt.show()

# %% [markdown]
# # Combined Visualization Map

# %%
plt.figure(figsize=(8,8))

# ======================
# 1) Heatmap (background)
# ======================
grid = df.groupby(["x","y"]).size().unstack().fillna(0)

plt.imshow(
    grid,
    origin="lower",
    cmap="Blues",
    alpha=0.6
)

# ======================
# 2) Sensors
# ======================
plt.scatter(
    df["x"],
    df["y"],
    s=1,
    alpha=0.3,
    color="black",
    label="Sensors"
)

# ======================
# 3) High Traffic
# ======================
high_traffic = df[df["traffic_level"] == 2]

plt.scatter(
    high_traffic["x"],
    high_traffic["y"],
    s=8,
    color="red",
    label="High Traffic"
)

# ======================
# Final touches
# ======================
plt.colorbar(label="Sensor Density")
plt.title("Combined Traffic Map (Sensors + Hotspots)")
plt.xlabel("X Grid")
plt.ylabel("Y Grid")
plt.legend()
plt.grid(alpha=0.2)

plt.show()

# %% [markdown]
# ---
#
#
# # **2] Fitness Function & Covering Simulation**
#
#
# ---

# %%
# Convert Heatmap Into Numerical Grid

grid = heatmap.fillna(0).values   # MUST be used everywhere
n, m = grid.shape
RADIUS = PARAMS["radius"]

# %%
def coverage(chromosome, grid, R=RADIUS):

    n, m = grid.shape

    covered = set()
    coverage_count = [[0]*m for _ in range(n)]
    sensor_covering = {}

    for (si, sj) in chromosome:
        sensor_cells = set()

        for i in range(max(0, si-R), min(n, si+R+1)):
           for j in range(max(0, sj-R), min(m, sj+R+1)):
               d = ((si - i)**2 + (sj - j)**2) ** 0.5

               if d <= R:
                 covered.add((i, j))
                 sensor_cells.add((i, j))
                 coverage_count[i][j] += 1

        sensor_covering[(si, sj)] = sensor_cells

    total_coverage = sum(grid[i][j] for (i, j) in covered)

    return total_coverage, coverage_count, covered, sensor_covering

# %%
def get_overlap_pairs(sensor_covering):

    overlap_map = {}

    sensors = list(sensor_covering.keys())

    for s1, s2 in combinations(sensors, 2):
        overlap = sensor_covering[s1] & sensor_covering[s2]

        if overlap:
            overlap_map.setdefault(s1, []).append(s2)

    return overlap_map

# %%
def compute_overlap(grid, coverage_count):

    overlap = 0

    for i in range(grid.shape[0]):
        for j in range(grid.shape[1]):
            if coverage_count[i][j] > 1:
                overlap += grid[i][j]

    return overlap


def compute_uncovered(grid, covered):

    uncovered = 0

    for i in range(grid.shape[0]):
        for j in range(grid.shape[1]):
            if (i, j) not in covered:
                uncovered += grid[i][j]

    return uncovered


# Constraint: minimum distance between sensors
""" def distance_penalty(chromosome, min_dist=3):

    penalty = 0
    for i in range(len(chromosome)):
        for j in range(i+1, len(chromosome)):
            d = np.linalg.norm(np.array(chromosome[i]) - np.array(chromosome[j]))
            if d < min_dist:
                penalty += 1
    return penalty """


def fitness(chromosome, grid, R=5,
            alpha=0.6, beta=0.2, gamma=0.1, delta=0.1):
  #max_coverage = grid.sum()
  #max_uncovered = grid.sum()
  #max_overlap = grid.sum() * len(chromosome)
  #max_sensors = len(set(zip(df["x"], df["y"]))) # This line is likely incorrect as df is not always available in the scope of fitness function when called outside the main script. If 'df' is indeed a global, this might work, otherwise it should be passed as an argument. For now, I'll keep it as is, focusing on the TypeError.

  total_coverage, coverage_count, covered, _ = coverage(chromosome, grid, R)

  overlap = compute_overlap(grid, coverage_count)
  uncovered = compute_uncovered(grid, covered)

# each is normalized to make total between (0 , 1)


  fitness_value = alpha * total_coverage - beta * overlap - gamma * len(chromosome) - delta * uncovered

  return max(0,  fitness_value)

# %%
def generate_chromosome(num_sensors,grid_shape):
    n, m = grid_shape
    return [
        (random.randint(0, n-1), random.randint(0, m-1))
        for _ in range(num_sensors)
    ]

# %%
def visualize(chromosome, covered,overlap_map):

    sx = [x for x, y in chromosome]
    sy = [y for x, y in chromosome]

    cx = [x for x, y in covered]
    cy = [y for x, y in covered]

    zx=[x for x, y in overlap_map]
    zy=[y for x, y in overlap_map]


    plt.figure(figsize=(8,8))

    plt.scatter(cx, cy, s=5, alpha=0.4, label="Covered")
    plt.scatter(sx, sy, c='red', s=80, label="Sensors")
    plt.scatter(zx, zy, c='black', s=80, label="overlaped")

    plt.title("Sensor Coverage")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.legend()
    plt.grid()
    plt.show()

# %% [markdown]
# ---
#
# # **3] Intialization & Selection**
#
#
# ---

# %% [markdown]
# # Intialization

# %% [markdown]
# Random Intialization

# %%
def random_init(pop_size, num_sensors, grid_shape):
    n, m = grid_shape

    return [
        [(random.randint(0,n-1), random.randint(0,m-1))
         for _ in range(num_sensors)]
        for _ in range(pop_size)
    ]

# %% [markdown]
# Heuristic Initialization

# %%
def heuristic_init(pop_size, num_sensors, grid):

    flat = []

    for i in range(len(grid)):
        for j in range(len(grid[0])):
            flat.append((i, j, grid[i][j]))

    flat.sort(key=lambda x: x[2], reverse=True) #  Sort by traffic
    top_cells = [(i, j) for i, j, _ in flat[:100]] # Top 100 cells
    population = []

    for _ in range(pop_size):
        chromosome = random.sample(top_cells, num_sensors)
        population.append(chromosome)

    return population

# %% [markdown]
# # Selections

# %% [markdown]
# Tournament Selection

# %%
def tournament_selection(population, fitnesses, k=3):

    selected = []

    for _ in range(len(population)):

        idx = random.sample(range(len(population)), k)

        best = idx[0]
        for i in idx:
            if fitnesses[i] > fitnesses[best]:
                best = i

        selected.append(population[best])

    return selected

# %% [markdown]
# Roulette Wheel Selection

# %%
def roulette_selection(population, fitnesses):
    min_fit = min(fitnesses)
    shifted = [f - min_fit + 1e-6 for f in fitnesses]

    total = sum(shifted)

    if total == 0:
        return random.choices(population, k=len(population))

    probs = [f / total for f in shifted]

    return random.choices(population, weights=probs, k=len(population))

# %% [markdown]
# SUS (Stochastic Universal Sampling)

# %%
def sus_selection(population, fitnesses):

    min_fit = min(fitnesses)
    shifted = [f - min_fit + 1e-6 for f in fitnesses]

    total = sum(shifted)

    if total == 0:
        return random.sample(population, len(population))

    probs = [f / total for f in shifted]

    cum = np.cumsum(probs)

    N = len(population)
    start = random.random() / N
    pointers = [start + i*(1/N) for i in range(N)]

    selected = []

    for p in pointers:
        for i in range(len(cum)):
            if p <= cum[i]:
                selected.append(population[i])
                break

    return selected

# %% [markdown]
# Over-Selection

# %%
def over_selection(population, fitnesses, top_ratio=0.5, elite_pressure=0.8):

    # sort population by fitness (best → worst)
    idx = np.argsort(fitnesses)[::-1]
    sorted_pop = [population[i] for i in idx]


    split = int(len(population) * top_ratio)

    top_group = sorted_pop[:split]
    bottom_group = sorted_pop[split:]

    selected = []

    # build new parent pool
    for _ in range(len(population)):

        if random.random() < elite_pressure:
            selected.append(random.choice(top_group))
        else:
            selected.append(random.choice(bottom_group))

    return selected

# %% [markdown]
# #Elitism

# %%
def elitism(population, fitnesses, elite_size=2):
    idx = np.argsort(fitnesses)[::-1]
    elite = [population[i] for i in idx[:elite_size]]
    return elite

# %% [markdown]
# # Generational Replacement

# %%
"""def generational_replacement(offspring, elite, pop_size):
    new_population = elite + offspring
    return new_population[:pop_size]"""
# Out:
# 'def generational_replacement(offspring, elite, pop_size):\n    new_population = elite + offspring\n    return new_population[:pop_size]'

# %% [markdown]
# #Rank-Based Survivor Selection

# %%
def rank_based_survivor(population, fitnesses):

    idx = np.argsort(fitnesses)
    sorted_pop = [population[i] for i in idx]
    weights = np.arange(1, len(population)+1)
    probs = weights / sum(weights)
    selected_idx = np.random.choice(
        len(population),
        size=len(population),
        p=probs
    )

    return [sorted_pop[i] for i in selected_idx]

# %%
def evaluate_population(population, grid, R=5):

    return [fitness(ind, grid, R) for ind in population]

# %%
def adaptive_tournament_k(gen, generations):

    return max(2, int(5 * (1 - gen / generations)))

# %% [markdown]
# ---
#
# # **4] Crossover & Mutation & Diversity**
#
# ---

# %%
def repair(individual, grid_shape, num_sensors):

    n, m = grid_shape

    repaired = [(int(x), int(y)) for x, y in individual]

    repaired = list(dict.fromkeys(repaired))  # remove duplicates only

    # instead of random filling → reuse existing structure
    while len(repaired) < num_sensors:
        repaired.append(random.choice(repaired))

    return repaired[:num_sensors]


def one_point_crossover(p1, p2, num_sensors, grid):

    point = num_sensors // 2
    child = p1[:point] + p2[point:]

    return repair(child, grid.shape, num_sensors)

def uniform_crossover(p1, p2, num_sensors, grid):

    child = []

    for i in range(num_sensors):
        gene = p1[i] if random.random() < 0.5 else p2[i]
        if gene not in child:
            child.append(gene)

    return repair(child, grid.shape, num_sensors)

# %%
def random_shift(individual, grid, mutation_rate=0.2):

    new_ind = individual.copy()

    for i in range(len(new_ind)):
        if random.random() < mutation_rate:

            x, y = new_ind[i]

            nx = max(0, min(grid.shape[0] - 1, x + random.randint(-2, 2)))
            ny = max(0, min(grid.shape[1] - 1, y + random.randint(-2, 2)))

            new_ind[i] = (nx, ny)

    return repair(new_ind, grid.shape, len(individual))

# RANDOM RESET MUTATION
def random_reset(individual, grid, mutation_rate=0.2):

    new_ind = individual.copy()

    for i in range(len(new_ind)):
        if random.random() < mutation_rate:

            nx = random.randint(0, grid.shape[0] - 1)
            ny = random.randint(0, grid.shape[1] - 1)

            new_ind[i] = (nx, ny)

    return repair(new_ind, grid.shape, len(individual))

# %%
def diversity_basic(population, threshold=0.8):

    new_pop = []

    for ind in population:

        keep = True

        for kept in new_pop:
            similarity = len(set(ind) & set(kept)) / len(ind)

            if similarity > threshold:
                keep = False
                break

        if keep:
            new_pop.append(ind)

    return new_pop if len(new_pop) > 0 else population


# STRONG DIVERSITY
def diversity_strong(population, threshold=0.6):

    new_pop = []

    for ind in population:

        keep = True

        for kept in new_pop:
            similarity = len(set(ind) & set(kept)) / len(ind)

            if similarity > threshold:
                keep = False
                break

        if keep:
            new_pop.append(ind)

    return new_pop if len(new_pop) >= 2 else population

# %%
def adaptive_crossover(gen, generations):
    start = 0.9
    end = 0.5
    return start - (start - end) * (gen / generations)

# %%
def adaptive_mutation(gen, generations):
    start = 0.2
    end = 0.1
    return start - (start - end) * (gen / generations)

# %% [markdown]
# ---
#
# # **5] GA LOOP**
#
# ---

# %%
def log_parameters(gen, mutation_rate, crossover_rate, k):

    print(f"""
    Generation {gen}
    Mutation Rate   : {mutation_rate:.3f}
    Crossover Rate  : {crossover_rate:.3f}
    Tournament K    : {k}
    """)

# %%
def run_ga(grid,
           pop_size=30,
           num_sensors=10,
           generations=30,

           selection_method="tournament",
           crossover_type="uniform",
           mutation_type="shift",
           diversity_type="basic",
           survivor_method="elitism",
           init_method="heuristic",

           use_de=False,
           de_F=0.5,
           de_CR=0.7,
           de_apply_rate=0.5,

           seed=None):

    # SEED
    if seed is not None:
      random.seed(seed)
      np.random.seed(seed)

    # INIT
    if init_method == "random":
       population = random_init(pop_size, num_sensors, grid.shape)
    else:
       population = heuristic_init(pop_size, num_sensors, grid)

    snapshots = []
    best_history = []
    avg_history = []
    diversity_history = []
    best_chromosome = None # Initialize best_chromosome

    elite_size = 4
    # dim = num_sensors * 2 # This variable is not used if not doing DE and can be removed or used conditionally
    snapshot_gens = [0, generations // 2, generations - 1]


    # MAIN LOOP
    for gen in range(generations):


        # ADAPTIVE CONTROL
        mutation_rate = adaptive_mutation(gen, generations)
        crossover_rate = adaptive_crossover(gen, generations)
        k = max(2, min(10, adaptive_tournament_k(gen, generations) + 2))
        log_parameters(gen, mutation_rate, crossover_rate, k)


        # FITNESS (of current generation's population)
        fitnesses = evaluate_population(population, grid, R=PARAMS["radius"])


        # SELECTION (parents from current generation)
        if selection_method == "tournament":
           parents = tournament_selection(population, fitnesses, k)
        elif selection_method == "roulette":
           parents = roulette_selection(population, fitnesses)
        elif selection_method == "sus":
           parents = sus_selection(population, fitnesses)
        elif selection_method == "over":
           parents = over_selection(population, fitnesses)
        else:
           parents = tournament_selection(population, fitnesses, k)

        # Determine elites from the *current* population before generating offspring.
        # This ensures 'elites' is always defined.
        current_elites = elitism(population, fitnesses, elite_size)

        # OFFSPRING GENERATION
        offspring_generated = []

        # Generate non-elite offspring to fill the remaining population slots
        while len(offspring_generated) < pop_size - elite_size:

            # Ensure parents list has at least two elements for random.sample
            if len(parents) < 2:
                # If too few parents, duplicate one or take a random one from original population
                p1 = random.choice(parents) if parents else generate_chromosome(num_sensors, grid.shape)
                p2 = random.choice(parents) if parents else generate_chromosome(num_sensors, grid.shape)
                if len(parents) == 1: # If only one parent, ensure p2 is different if possible
                    p2 = random.choice(population) if population else generate_chromosome(num_sensors, grid.shape)
            else:
                p1, p2 = random.sample(parents, 2)

            # Crossover
            if random.random() < crossover_rate:
                if crossover_type == "onepoint":
                    child = one_point_crossover(p1, p2, num_sensors, grid)
                else:
                    child = uniform_crossover(p1, p2, num_sensors, grid)
            else:
                child = p1.copy()

            # Mutation
            if mutation_type == "shift":
                child = random_shift(child, grid, mutation_rate)
            else:
                child = random_reset(child, grid, mutation_rate)

            offspring_generated.append(child)

        # Combine the newly generated offspring with the elites from the previous generation
        candidate_next_population = offspring_generated + current_elites

        # DIVERSITY
        if diversity_type == "basic":
            candidate_next_population = diversity_basic(candidate_next_population)
        else:
            candidate_next_population = diversity_strong(candidate_next_population)

        # Ensure the candidate population is not too small after diversity application
        while len(candidate_next_population) < pop_size:
            # Refill with a random parent or a newly generated chromosome
            if parents:
                candidate_next_population.append(random.choice(parents))
            else:
                candidate_next_population.append(generate_chromosome(num_sensors, grid.shape))

        # SURVIVOR SELECTION: Form the actual 'population' for the next generation
        if survivor_method == "elitism":
           # Elites are already in `candidate_next_population`, so just trim to `pop_size`
           population = candidate_next_population[:pop_size]
        elif survivor_method == "rank":
           # Need to evaluate fitness of the candidate next population for rank-based selection
           candidate_fitnesses = evaluate_population(candidate_next_population, grid, R=PARAMS["radius"])
           population = rank_based_survivor(candidate_next_population, candidate_fitnesses)[:pop_size]
        else: # Default: generational replacement (offspring + elites, trimmed)
           population = candidate_next_population[:pop_size]


        #  OPTIONAL DE STEP (HYBRID PLUG) - This part operates on the *newly formed* `population`
        if use_de:
            vector_pop = [encode(ind) for ind in population]
            current_pop_len = len(vector_pop)

            # Only apply DE if there are enough individuals for mutation operation (need at least 4 distinct individuals)
            if current_pop_len >= 4:
                n_de_to_apply = int(de_apply_rate * current_pop_len)
                n_de_to_apply = min(n_de_to_apply, current_pop_len)

                for i in random.sample(range(current_pop_len), n_de_to_apply):
                    mutant = de_mutation(vector_pop, i, de_F)
                    trial = de_crossover(vector_pop[i], mutant, de_CR)

                    trial_chrom = repair_de(decode(trial), grid.shape, num_sensors)
                    target_chrom = repair_de(decode(vector_pop[i]), grid.shape, num_sensors)

                    if fitness(trial_chrom, grid) > fitness(target_chrom, grid): # Compare fitness of repaired chromosomes
                        vector_pop[i] = trial

                population = [
                    repair_de(decode(v), grid.shape, num_sensors)
                    for v in vector_pop
                ]
            # else: if current_pop_len < 4, DE step is skipped for this generation


        # REFILL (Optional: if population size somehow drops below pop_size during or after DE, or on specific generations)
        # This step is mostly redundant now if the survivor selection and diversity handling are robust.
        # Only re-add if population is explicitly too small and it's a refill generation
        if gen % 5 == 0 and len(population) < pop_size:
            population.append(generate_chromosome(num_sensors, grid.shape))
        # Ensure population does not exceed pop_size from refill (should already be handled by [:pop_size])
        population = population[:pop_size]
        div_val = population_diversity(population)
        diversity_history.append(div_val)

        print(f"Diversity = {div_val:.4f}")


        # EVALUATION (of the final population for this generation, used for logging and best_chromosome update)
        fitnesses = evaluate_population(population, grid, R=PARAMS["radius"])

        best_gen_fitness = max(fitnesses)
        avg_gen_fitness = np.mean(fitnesses)
        best_gen_idx = np.argmax(fitnesses)


        # Update overall best chromosome
        # Check `best_history` is not empty before calling max()
        if not best_history or best_gen_fitness > max(best_history):
            best_chromosome = population[best_gen_idx]

        best_history.append(best_gen_fitness)
        avg_history.append(avg_gen_fitness)
        if gen in [0, generations//2, generations-1]:
                   snapshots.append((gen, best_chromosome))


        # LOGGING
        print(
            f"[GA{'+DE' if use_de else ''}] Gen {gen:02d} | "
            f"Best={best_gen_fitness:.4f} | Avg={avg_gen_fitness:.4f}"
        )

    return max(best_history), best_history, avg_history, best_chromosome, diversity_history, snapshots

# %% [markdown]
# ---
#
# # **6] Differential Evolution & DE LOOP**
#
# ---

# %%
def encode(chromosome):
    # [(x,y), (x,y)] → [x1,y1,x2,y2,...]
    return np.array([coord for point in chromosome for coord in point])


def decode(vector):
    # [x1,y1,x2,y2,...] → [(x,y),(x,y)]
    return [(int(vector[i]), int(vector[i+1]))
            for i in range(0, len(vector), 2)]

# %%
# This repair function: fixes boundaries & fixes float → int
def repair_de(individual, grid_shape, num_sensors):

    n, m = grid_shape

    repaired = []
    for x, y in individual:
        x = int(np.clip(x, 0, n-1))
        y = int(np.clip(y, 0, m-1))
        repaired.append((x, y))

    repaired = list(dict.fromkeys(repaired))

    while len(repaired) < num_sensors:
        repaired.append((random.randint(0,n-1), random.randint(0,m-1)))

    return repaired[:num_sensors]

# %% [markdown]
# # Mutation

# %%
# v = x1 + F * (x2 - x3)
def de_mutation(population_vectors, i, F=0.5):

    idxs = list(range(len(population_vectors)))
    idxs.remove(i)

    a, b, c = random.sample(idxs, 3)

    x1 = population_vectors[a]
    x2 = population_vectors[b]
    x3 = population_vectors[c]

    mutant = x1 + F * (x2 - x3)

    return mutant

# %% [markdown]
# # Crossover

# %%
def de_crossover(target, mutant, CR=0.7):

    trial = np.copy(target)

    for i in range(len(target)):
        if random.random() < CR:
            trial[i] = mutant[i]

    return trial

# %% [markdown]
# #DE loop

# %%
def run_de(grid,
           pop_size=30,
           num_sensors=10,
           generations=30,
           seed=None):

    if seed is not None:
        random.seed(seed)
        np.random.seed(seed)

    population = [
        encode(generate_chromosome(num_sensors, grid.shape))
        for _ in range(pop_size)
    ]

    best_history = []
    avg_history = []
    diversity_history = []   # ✅ ADD
    snapshots = []           # ✅ ADD

    best_chromosome = None
    best_fitness_so_far = -float("inf")

    dim = num_sensors * 2

    for gen in range(generations):

        F = 0.3 + 0.4 * random.random()
        CR = 0.6 + 0.3 * (gen / generations)

        new_population = []

        for i in range(pop_size):

            x = population[i]
            idxs = list(range(pop_size))
            idxs.remove(i)

            a, b, c = random.sample(idxs, 3)

            x1 = population[a]
            x2 = population[b]
            x3 = population[c]

            mutant = x1 + F * (x2 - x3)

            trial = np.copy(x)

            for j in range(dim):
                if random.random() < CR:
                    trial[j] = mutant[j]

            trial_chrom = repair(decode(trial), grid.shape, num_sensors)
            target_chrom = repair(decode(x), grid.shape, num_sensors)

            if fitness(trial_chrom, grid) > fitness(target_chrom, grid):
                new_population.append(trial)
            else:
                new_population.append(x)

        population = new_population

        # ===== FITNESS =====
        fitnesses = [
            fitness(repair(decode(ind), grid.shape, num_sensors), grid)
            for ind in population
        ]

        best = max(fitnesses)
        avg = np.mean(fitnesses)

        best_history.append(best)
        avg_history.append(avg)

        # ===== DIVERSITY =====
        diversity_history.append(population_diversity(population))

        # ===== BEST CHROMOSOME FIX =====
        best_idx = np.argmax(fitnesses)

        if fitnesses[best_idx] > best_fitness_so_far:
            best_fitness_so_far = fitnesses[best_idx]
            best_chromosome = repair(
                decode(population[best_idx]),
                grid.shape,
                num_sensors
            )

        # ===== SNAPSHOT =====
        snapshots.append((gen, best_chromosome))

        print(f"[DE] Gen {gen:02d} | Best={best:.4f} | Avg={avg:.4f}")

    return max(best_history), best_history, avg_history, best_chromosome, diversity_history, snapshots

# %%
"""def run_experiments(grid, runs=10):


    de_results = []
    ga_best = 0 # Initialize ga_best here

    for r in range(runs):

        print("\n" + "="*50)
        print(f"RUN {r+1}/{runs}")
        print("="*50)


        # =========================
        # DE ONLY
        # =========================
        print("\n[DE] Running...")
        de_best, de_hist, _ = run_de(grid)
        de_results.append(de_best)
        print(f"[DE] Best Fitness = {de_best:.4f}")



        # =========================
        # RUN SUMMARY
        # =========================
        print("\n--- RUN SUMMARY ---")
        print(f"DE      : {de_best:.4f}")


    return  de_results"""
# Out:
# 'def run_experiments(grid, runs=10):\n\n\n    de_results = []\n    ga_best = 0 # Initialize ga_best here\n\n    for r in range(runs):\n\n        print("\n" + "="*50)\n        print(f"RUN {r+1}/{runs}")\n        print("="*50)\n\n\n        # =========================\n        # DE ONLY\n        # =========================\n        print("\n[DE] Running...")\n        de_best, de_hist, _ = run_de(grid)\n        de_results.append(de_best)\n        print(f"[DE] Best Fitness = {de_best:.4f}")\n\n\n\n        # =========================\n        # RUN SUMMARY\n        # =========================\n        print("\n--- RUN SUMMARY ---")\n        print(f"DE      : {de_best:.4f}")\n\n\n    return  de_results'

# %% [markdown]
# ---
#
# # **7] Experiments & Helper Functions**
#
# ---

# %%
def get_coverage_map(chromosome, grid, R):

    n, m = grid.shape
    covered = set()

    for (si, sj) in chromosome:
        for i in range(max(0, si-R), min(n, si+R+1)):
            for j in range(max(0, sj-R), min(m, sj+R+1)):
                if np.linalg.norm([si-i, sj-j]) <= R:
                    covered.add((i, j))

    return covered

# %%
def coverage_ratio(chromosome, grid, R):
    covered = get_coverage_map(chromosome, grid, R)
    total_cells = grid.shape[0] * grid.shape[1]
    return len(covered) / total_cells

# %%
def population_diversity(population):
    arr = np.array([np.array(ind).flatten() for ind in population])
    return np.mean(np.std(arr, axis=0))

# %%
from joblib import Parallel, delayed

# =========================
# PARALLEL HELPERS
# =========================

def single_run_ga_full(grid, sel, cross, mut, div, init, surv, sensors, algo, seed):
    best, hist, avg, best_chrom, div_hist, snapshots = run_ga(
     grid,
     selection_method=sel,
     crossover_type=cross,
     mutation_type=mut,
     diversity_type=div,
     survivor_method=surv,
     init_method=init,
     num_sensors=sensors,
     use_de=(algo == "HYBRID"),
     seed=seed
    )

    cov = coverage_ratio(best_chrom, grid, PARAMS["radius"])

    return best, hist, div_hist, snapshots, cov

def single_run_de_full(grid, sensors, seed):

    best, hist, avg, best_chrom, div_hist, snapshots = run_de(
        grid,
        num_sensors=sensors,
        seed=seed
    )

    cov = coverage_ratio(best_chrom, grid, PARAMS["radius"])

    return best, hist, div_hist, snapshots, cov


# =========================
# MAIN EXPERIMENT FUNCTION
# =========================

def run_experiments(grid, runs=10):

    results = []

    selection_methods = ["tournament", "roulette", "sus", "over"]
    crossover_types = ["onepoint", "uniform"]
    mutation_types = ["shift", "reset"]
    diversity_types = ["basic", "strong"]

    init_methods = ["random", "heuristic"]
    survivor_methods = ["elitism", "rank"]
    sensor_values = [5, 10, 15]

    algorithms = ["GA", "DE", "HYBRID"]

    all_histories = {
        "GA": [],
        "DE": [],
        "HYBRID": []
    }
    all_snapshots = {
        "GA": [],
        "DE": [],
        "HYBRID": []
    }
    all_diversity = {
        "GA": [],
        "DE": [],
        "HYBRID": []
    }

    for algo in algorithms:

        print("\n" + "#"*70)
        print(f"ALGORITHM: {algo}")
        print("#"*70)

        # =========================
        # GA & HYBRID
        # =========================
        if algo in ["GA", "HYBRID"]:

            for sel in selection_methods:
                for cross in crossover_types:
                    for mut in mutation_types:
                        for div in diversity_types:
                            for init in init_methods:
                                for surv in survivor_methods:
                                    for sensors in sensor_values:

                                        print(f"\nCONFIG: {sel}|{cross}|{mut}|{div}|{init}|{surv}|S={sensors}")


                                        # generate seeds once
                                        seeds = [random.randint(0, 100000) for _ in range(runs)]
                                        print("\nSeed list per run:")
                                        for i, s in enumerate(seeds):
                                                print(f"Run {i+1}: Seed = {s}")

                                        # PARALLEL EXECUTION
                                        results_parallel = Parallel(n_jobs=-1)(
                                            delayed(single_run_ga_full)(
                                                grid, sel, cross, mut, div, init, surv, sensors, algo, seed
                                            )
                                            for seed in seeds
                                        )

                                        scores = [r[0] for r in results_parallel]
                                        hist_collection = [r[1] for r in results_parallel]
                                        div_collection = [r[2] for r in results_parallel]
                                        snapshots_collection = [r[3] for r in results_parallel]


                                        avg_hist = np.mean(hist_collection, axis=0)
                                        all_histories[algo].append(avg_hist)
                                        all_diversity[algo].append(np.mean(div_collection, axis=0))
                                        all_snapshots[algo].append({
                                               "config": (sel, cross, mut, div, init, surv, sensors),
                                               "runs": snapshots_collection
                                        })



                                        print(f"Mean = {np.mean(scores):.4f} | Max = {np.max(scores):.4f}")

                                        results.append({
                                            "algorithm": algo,
                                            "selection": sel,
                                            "crossover": cross,
                                            "mutation": mut,
                                            "diversity": div,
                                            "init": init,
                                            "survivor": surv,
                                            "sensors": sensors,
                                            "mean": np.mean(scores),
                                            "std": np.std(scores),
                                            "max": np.max(scores),
                                            "seeds": [{"run": i, "seed": s} for i, s in enumerate(seeds)],
                                            "scores": scores
                                        })

        # =========================
        # DE ONLY
        # =========================
        else:

            for sensors in sensor_values:

                print(f"\nCONFIG: DE | Sensors={sensors}")

                seeds = [random.randint(0, 100000) for _ in range(runs)]

                results_parallel = Parallel(n_jobs=-1)(
                    delayed(single_run_de_full)(grid, sensors, seed)
                    for seed in seeds
                )

                scores = [r[0] for r in results_parallel]
                hist_collection = [r[1] for r in results_parallel]
                div_collection = [r[2] for r in results_parallel]

                avg_hist = np.mean(hist_collection, axis=0)
                all_histories[algo].append(avg_hist)
                all_diversity[algo].append(np.mean(div_collection, axis=0))

                print(f"Mean = {np.mean(scores):.4f} | Max = {np.max(scores):.4f}")

                results.append({
                    "algorithm": "DE",
                    "sensors": sensors,
                    "mean": np.mean(scores),
                    "std": np.std(scores),
                    "max": np.max(scores),
                    "seeds": seeds
                })

    return results, all_histories, all_diversity, all_snapshots

# %%
best_hybrid, hist_hybrid, avg_hybrid, hybrid_best_solution, div_hist, snapshots = run_ga(
    generations=30,
    grid=grid,
    use_de=True
)
# Out:
#     Generation 0
#     Mutation Rate   : 0.200
#     Crossover Rate  : 0.900
#     Tournament K    : 7
#
# Diversity = 9.1119
# [GA+DE] Gen 00 | Best=14.2431 | Avg=11.5840
#
#     Generation 1
#     Mutation Rate   : 0.197
#     Crossover Rate  : 0.887
#     Tournament K    : 6
#
# Diversity = 6.1150
# [GA+DE] Gen 01 | Best=14.9982 | Avg=12.6971
#
#     Generation 2
#     Mutation Rate   : 0.193
#     Crossover Rate  : 0.873
#     Tournament K    : 6
#
# Diversity = 4.3323
# [GA+DE] Gen 02 | Best=15.1302 | Avg=13.7955
#
#     Generation 3
#     Mutation Rate   : 0.190
#     Crossover Rate  : 0.860
#     Tournament K    : 6
#
# Diversity = 4.6434
# [GA+DE] Gen 03 | Best=15.1302 | Avg=13.8647
#
#     Generation 4
#     Mutation Rate   : 0.187
#     Crossover Rate  : 0.847
#     Tournament K    : 6
#
# Diversity = 5.4127
# [GA+DE] Gen 04 | Best=15.2332 | Avg=14.1978
#
#     Generation 5
#     Mutation Rate   : 0.183
#     Crossover Rate  : 0.833
#     Tournament K    : 6
#
# Diversity = 6.3476
# [GA+DE] Gen 05 | Best=15.6057 | Avg=13.7404
#
#     Generation 6
#     Mutation Rate   : 0.180
#     Crossover Rate  : 0.820
#     Tournament K    : 6
#
# Diversity = 6.5424
# [GA+DE] Gen 06 | Best=15.8080 | Avg=13.7168
#
#     Generation 7
#     Mutation Rate   : 0.177
#     Crossover Rate  : 0.807
#     Tournament K    : 5
#
# Diversity = 6.0848
# [GA+DE] Gen 07 | Best=15.8080 | Avg=13.6597
#
#     Generation 8
#     Mutation Rate   : 0.173
#     Crossover Rate  : 0.793
#     Tournament K    : 5
#
# Diversity = 4.0035
# [GA+DE] Gen 08 | Best=16.3652 | Avg=15.0338
#
#     Generation 9
#     Mutation Rate   : 0.170
#     Crossover Rate  : 0.780
#     Tournament K    : 5
#
# Diversity = 1.4537
# [GA+DE] Gen 09 | Best=16.3652 | Avg=15.3258
#
#     Generation 10
#     Mutation Rate   : 0.167
#     Crossover Rate  : 0.767
#     Tournament K    : 5
#
# Diversity = 1.0339
# [GA+DE] Gen 10 | Best=16.7736 | Avg=15.5843
#
#     Generation 11
#     Mutation Rate   : 0.163
#     Crossover Rate  : 0.753
#     Tournament K    : 5
#
# Diversity = 0.7767
# [GA+DE] Gen 11 | Best=16.8384 | Avg=16.0593
#
#     Generation 12
#     Mutation Rate   : 0.160
#     Crossover Rate  : 0.740
#     Tournament K    : 5
#
# Diversity = 0.8170
# [GA+DE] Gen 12 | Best=17.2727 | Avg=16.2661
#
#     Generation 13
#     Mutation Rate   : 0.157
#     Crossover Rate  : 0.727
#     Tournament K    : 4
#
# Diversity = 0.7898
# [GA+DE] Gen 13 | Best=17.3813 | Avg=16.5914
#
#     Generation 14
#     Mutation Rate   : 0.153
#     Crossover Rate  : 0.713
#     Tournament K    : 4
#
# Diversity = 0.8568
# [GA+DE] Gen 14 | Best=17.6106 | Avg=16.6599
#
#     Generation 15
#     Mutation Rate   : 0.150
#     Crossover Rate  : 0.700
#     Tournament K    : 4
#
# Diversity = 0.9467
# [GA+DE] Gen 15 | Best=17.5121 | Avg=16.9795
#
#     Generation 16
#     Mutation Rate   : 0.147
#     Crossover Rate  : 0.687
#     Tournament K    : 4
#
# Diversity = 1.2377
# [GA+DE] Gen 16 | Best=17.8674 | Avg=16.8401
#
#     Generation 17
#     Mutation Rate   : 0.143
#     Crossover Rate  : 0.673
#     Tournament K    : 4
#
# Diversity = 1.3363
# [GA+DE] Gen 17 | Best=17.8674 | Avg=16.7346
#
#     Generation 18
#     Mutation Rate   : 0.140
#     Crossover Rate  : 0.660
#     Tournament K    : 4
#
# Diversity = 1.1567
# [GA+DE] Gen 18 | Best=17.8120 | Avg=17.2192
#
#     Generation 19
#     Mutation Rate   : 0.137
#     Crossover Rate  : 0.647
#     Tournament K    : 4
#
# Diversity = 0.7296
# [GA+DE] Gen 19 | Best=18.0014 | Avg=17.5697
#
#     Generation 20
#     Mutation Rate   : 0.133
#     Crossover Rate  : 0.633
#     Tournament K    : 4
#
# Diversity = 0.9751
# [GA+DE] Gen 20 | Best=18.0393 | Avg=17.3622
#
#     Generation 21
#     Mutation Rate   : 0.130
#     Crossover Rate  : 0.620
#     Tournament K    : 4
#
# Diversity = 0.8457
# [GA+DE] Gen 21 | Best=18.1186 | Avg=17.4228
#
#     Generation 22
#     Mutation Rate   : 0.127
#     Crossover Rate  : 0.607
#     Tournament K    : 4
#
# Diversity = 0.6598
# [GA+DE] Gen 22 | Best=18.1186 | Avg=17.5610
#
#     Generation 23
#     Mutation Rate   : 0.123
#     Crossover Rate  : 0.593
#     Tournament K    : 4
#
# Diversity = 0.4981
# [GA+DE] Gen 23 | Best=18.2365 | Avg=17.8514
#
#     Generation 24
#     Mutation Rate   : 0.120
#     Crossover Rate  : 0.580
#     Tournament K    : 4
#
# Diversity = 0.5653
# [GA+DE] Gen 24 | Best=18.2365 | Avg=17.7969
#
#     Generation 25
#     Mutation Rate   : 0.117
#     Crossover Rate  : 0.567
#     Tournament K    : 4
#
# Diversity = 0.5632
# [GA+DE] Gen 25 | Best=18.2365 | Avg=17.7790
#
#     Generation 26
#     Mutation Rate   : 0.113
#     Crossover Rate  : 0.553
#     Tournament K    : 4
#
# Diversity = 0.6283
# [GA+DE] Gen 26 | Best=18.2933 | Avg=17.6621
#
#     Generation 27
#     Mutation Rate   : 0.110
#     Crossover Rate  : 0.540
#     Tournament K    : 4
#
# Diversity = 0.5956
# [GA+DE] Gen 27 | Best=18.3405 | Avg=17.9348
#
#     Generation 28
#     Mutation Rate   : 0.107
#     Crossover Rate  : 0.527
#     Tournament K    : 4
#
# Diversity = 0.5321
# [GA+DE] Gen 28 | Best=18.4408 | Avg=17.9309
#
#     Generation 29
#     Mutation Rate   : 0.103
#     Crossover Rate  : 0.513
#     Tournament K    : 4
#
# Diversity = 0.5094
# [GA+DE] Gen 29 | Best=18.4752 | Avg=18.2085

# %%
results, histories, all_diversity, all_snapshots = run_experiments(grid, runs=5)
# Out:
# ######################################################################
# ALGORITHM: GA
# ######################################################################
#
# CONFIG: tournament|onepoint|shift|basic|random|elitism|S=5
#
# Seed list per run:
# Run 1: Seed = 46734
# Run 2: Seed = 87919
# Run 3: Seed = 30889
# Run 4: Seed = 56012
# Run 5: Seed = 68491
# Mean = 10.7321 | Max = 11.8184
#
# CONFIG: tournament|onepoint|shift|basic|random|elitism|S=10
#
# Seed list per run:
# Run 1: Seed = 77421
# Run 2: Seed = 57193
# Run 3: Seed = 67209
# Run 4: Seed = 31983
# Run 5: Seed = 57917
# Mean = 16.9818 | Max = 17.8524
#
# CONFIG: tournament|onepoint|shift|basic|random|elitism|S=15
#
# Seed list per run:
# Run 1: Seed = 31492
# Run 2: Seed = 78641
# Run 3: Seed = 95220
# Run 4: Seed = 98340
# Run 5: Seed = 84764
# Mean = 18.5775 | Max = 18.8988
#
# CONFIG: tournament|onepoint|shift|basic|random|rank|S=5
#
# Seed list per run:
# Run 1: Seed = 76722
# Run 2: Seed = 85311
# Run 3: Seed = 65989
# Run 4: Seed = 61204
# Run 5: Seed = 89699
# Mean = 10.6371 | Max = 12.1336
#
# CONFIG: tournament|onepoint|shift|basic|random|rank|S=10
#
# Seed list per run:
# Run 1: Seed = 51820
# Run 2: Seed = 45510
# Run 3: Seed = 30514
# Run 4: Seed = 27648
# Run 5: Seed = 31448
# Mean = 16.3438 | Max = 17.4777
#
# CONFIG: tournament|onepoint|shift|basic|random|rank|S=15
#
# Seed list per run:
# Run 1: Seed = 91718
# Run 2: Seed = 91030
# Run 3: Seed = 37135
# Run 4: Seed = 18938
# Run 5: Seed = 90889
# Mean = 18.0051 | Max = 19.4026
#
# CONFIG: tournament|onepoint|shift|basic|heuristic|elitism|S=5
#
# Seed list per run:
# Run 1: Seed = 91823
# Run 2: Seed = 2532
# Run 3: Seed = 51160
# Run 4: Seed = 52647
# Run 5: Seed = 53005
# Mean = 12.6927 | Max = 12.9915
#
# CONFIG: tournament|onepoint|shift|basic|heuristic|elitism|S=10
#
# Seed list per run:
# Run 1: Seed = 97391
# Run 2: Seed = 87146
# Run 3: Seed = 94465
# Run 4: Seed = 64944
# Run 5: Seed = 47032
# Mean = 18.1562 | Max = 19.2026
#
# CONFIG: tournament|onepoint|shift|basic|heuristic|elitism|S=15
#
# Seed list per run:
# Run 1: Seed = 73465
# Run 2: Seed = 20482
# Run 3: Seed = 53701
# Run 4: Seed = 26466
# Run 5: Seed = 27985
# Mean = 18.4593 | Max = 19.0765
#
# CONFIG: tournament|onepoint|shift|basic|heuristic|rank|S=5
#
# Seed list per run:
# Run 1: Seed = 68533
# Run 2: Seed = 59026
# Run 3: Seed = 38102
# Run 4: Seed = 68970
# Run 5: Seed = 81190
# Mean = 12.0434 | Max = 12.6013
#
# CONFIG: tournament|onepoint|shift|basic|heuristic|rank|S=10
#
# Seed list per run:
# Run 1: Seed = 20907
# Run 2: Seed = 27900
# Run 3: Seed = 58957
# Run 4: Seed = 82119
# Run 5: Seed = 64947
# Mean = 17.6689 | Max = 18.3790
#
# CONFIG: tournament|onepoint|shift|basic|heuristic|rank|S=15
#
# Seed list per run:
# Run 1: Seed = 10494
# Run 2: Seed = 77430
# Run 3: Seed = 85549
# Run 4: Seed = 55504
# Run 5: Seed = 34196
# Mean = 18.5208 | Max = 18.6601
#
# CONFIG: tournament|onepoint|shift|strong|random|elitism|S=5
#
# Seed list per run:
# Run 1: Seed = 92653
# Run 2: Seed = 65103
# Run 3: Seed = 49830
# Run 4: Seed = 60434
# Run 5: Seed = 94164
# Mean = 10.0085 | Max = 12.4853
#
# CONFIG: tournament|onepoint|shift|strong|random|elitism|S=10
#
# Seed list per run:
# Run 1: Seed = 38237
# Run 2: Seed = 54338
# Run 3: Seed = 3364
# Run 4: Seed = 98831
# Run 5: Seed = 24082
# Mean = 14.9071 | Max = 16.5420
#
# CONFIG: tournament|onepoint|shift|strong|random|elitism|S=15
#
# Seed list per run:
# Run 1: Seed = 57522
# Run 2: Seed = 93043
# Run 3: Seed = 25622
# Run 4: Seed = 87260
# Run 5: Seed = 95113
# Mean = 17.1814 | Max = 18.0969
#
# CONFIG: tournament|onepoint|shift|strong|random|rank|S=5
#
# Seed list per run:
# Run 1: Seed = 14098
# Run 2: Seed = 14572
# Run 3: Seed = 84081
# Run 4: Seed = 65988
# Run 5: Seed = 52477
# Mean = 10.9488 | Max = 12.3839
#
# CONFIG: tournament|onepoint|shift|strong|random|rank|S=10
#
# Seed list per run:
# Run 1: Seed = 32689
# Run 2: Seed = 94340
# Run 3: Seed = 98929
# Run 4: Seed = 68595
# Run 5: Seed = 7524
# Mean = 14.8121 | Max = 16.4513
#
# CONFIG: tournament|onepoint|shift|strong|random|rank|S=15
#
# Seed list per run:
# Run 1: Seed = 76378
# Run 2: Seed = 24260
# Run 3: Seed = 12942
# Run 4: Seed = 24729
# Run 5: Seed = 67285
# Mean = 17.2522 | Max = 18.3282
#
# CONFIG: tournament|onepoint|shift|strong|heuristic|elitism|S=5
#
# Seed list per run:
# Run 1: Seed = 51536
# Run 2: Seed = 88354
# Run 3: Seed = 66880
# Run 4: Seed = 34355
# Run 5: Seed = 71745
# Mean = 11.6455 | Max = 12.8290
#
# CONFIG: tournament|onepoint|shift|strong|heuristic|elitism|S=10
#
# Seed list per run:
# Run 1: Seed = 54225
# Run 2: Seed = 49528
# Run 3: Seed = 38643
# Run 4: Seed = 36293
# Run 5: Seed = 954
# Mean = 17.4261 | Max = 18.6117
#
# CONFIG: tournament|onepoint|shift|strong|heuristic|elitism|S=15
#
# Seed list per run:
# Run 1: Seed = 29120
# Run 2: Seed = 67509
# Run 3: Seed = 75593
# Run 4: Seed = 41512
# Run 5: Seed = 49279
# Mean = 17.7944 | Max = 18.3235
#
# CONFIG: tournament|onepoint|shift|strong|heuristic|rank|S=5
#
# Seed list per run:
# Run 1: Seed = 43544
# Run 2: Seed = 94520
# Run 3: Seed = 70736
# Run 4: Seed = 85972
# Run 5: Seed = 42129
# Mean = 11.8188 | Max = 12.6945
#
# CONFIG: tournament|onepoint|shift|strong|heuristic|rank|S=10
#
# Seed list per run:
# Run 1: Seed = 8846
# Run 2: Seed = 57448
# Run 3: Seed = 71946
# Run 4: Seed = 9597
# Run 5: Seed = 8328
# Mean = 17.1220 | Max = 18.5592
#
# CONFIG: tournament|onepoint|shift|strong|heuristic|rank|S=15
#
# Seed list per run:
# Run 1: Seed = 75681
# Run 2: Seed = 64751
# Run 3: Seed = 98524
# Run 4: Seed = 58473
# Run 5: Seed = 74993
# Mean = 17.9304 | Max = 19.0364
#
# CONFIG: tournament|onepoint|reset|basic|random|elitism|S=5
#
# Seed list per run:
# Run 1: Seed = 54957
# Run 2: Seed = 1841
# Run 3: Seed = 29476
# Run 4: Seed = 3227
# Run 5: Seed = 39555
# Mean = 10.0780 | Max = 10.6285
#
# CONFIG: tournament|onepoint|reset|basic|random|elitism|S=10
#
# Seed list per run:
# Run 1: Seed = 85316
# Run 2: Seed = 80540
# Run 3: Seed = 2400
# Run 4: Seed = 57532
# Run 5: Seed = 32978
# Mean = 15.3843 | Max = 15.7880
#
# CONFIG: tournament|onepoint|reset|basic|random|elitism|S=15
#
# Seed list per run:
# Run 1: Seed = 75161
# Run 2: Seed = 80413
# Run 3: Seed = 53332
# Run 4: Seed = 63775
# Run 5: Seed = 12110
# Mean = 16.6904 | Max = 17.3001
#
# CONFIG: tournament|onepoint|reset|basic|random|rank|S=5
#
# Seed list per run:
# Run 1: Seed = 68487
# Run 2: Seed = 98955
# Run 3: Seed = 87276
# Run 4: Seed = 56394
# Run 5: Seed = 57832
# Mean = 10.0517 | Max = 11.4541
#
# CONFIG: tournament|onepoint|reset|basic|random|rank|S=10
#
# Seed list per run:
# Run 1: Seed = 41664
# Run 2: Seed = 96696
# Run 3: Seed = 71511
# Run 4: Seed = 34196
# Run 5: Seed = 8614
# Mean = 15.3904 | Max = 16.2825
#
# CONFIG: tournament|onepoint|reset|basic|random|rank|S=15
#
# Seed list per run:
# Run 1: Seed = 90528
# Run 2: Seed = 79974
# Run 3: Seed = 76058
# Run 4: Seed = 38978
# Run 5: Seed = 5606
# Mean = 16.7724 | Max = 17.4451
#
# CONFIG: tournament|onepoint|reset|basic|heuristic|elitism|S=5
#
# Seed list per run:
# Run 1: Seed = 78621
# Run 2: Seed = 20451
# Run 3: Seed = 89469
# Run 4: Seed = 94346
# Run 5: Seed = 92063
# Mean = 10.3592 | Max = 10.8040
#
# CONFIG: tournament|onepoint|reset|basic|heuristic|elitism|S=10
#
# Seed list per run:
# Run 1: Seed = 73713
# Run 2: Seed = 95464
# Run 3: Seed = 33118
# Run 4: Seed = 87000
# Run 5: Seed = 44764
# Mean = 16.1130 | Max = 17.4207
#
# CONFIG: tournament|onepoint|reset|basic|heuristic|elitism|S=15
#
# Seed list per run:
# Run 1: Seed = 45608
# Run 2: Seed = 33843
# Run 3: Seed = 41407
# Run 4: Seed = 50729
# Run 5: Seed = 58950
# Mean = 16.6828 | Max = 16.7715
#
# CONFIG: tournament|onepoint|reset|basic|heuristic|rank|S=5
#
# Seed list per run:
# Run 1: Seed = 99540
# Run 2: Seed = 1676
# Run 3: Seed = 17483
# Run 4: Seed = 98467
# Run 5: Seed = 98283
# Mean = 10.7090 | Max = 11.2103
#
# CONFIG: tournament|onepoint|reset|basic|heuristic|rank|S=10
#
# Seed list per run:
# Run 1: Seed = 96178
# Run 2: Seed = 62381
# Run 3: Seed = 97975
# Run 4: Seed = 1081
# Run 5: Seed = 49006
# Mean = 16.0619 | Max = 16.9768
#
# CONFIG: tournament|onepoint|reset|basic|heuristic|rank|S=15
#
# Seed list per run:
# Run 1: Seed = 11546
# Run 2: Seed = 90474
# Run 3: Seed = 66095
# Run 4: Seed = 23324
# Run 5: Seed = 49502
# Mean = 17.1958 | Max = 17.9629
#
# CONFIG: tournament|onepoint|reset|strong|random|elitism|S=5
#
# Seed list per run:
# Run 1: Seed = 38196
# Run 2: Seed = 49511
# Run 3: Seed = 60599
# Run 4: Seed = 85771
# Run 5: Seed = 32502
# Mean = 10.0279 | Max = 11.2101
#
# CONFIG: tournament|onepoint|reset|strong|random|elitism|S=10
#
# Seed list per run:
# Run 1: Seed = 19962
# Run 2: Seed = 8332
# Run 3: Seed = 74616
# Run 4: Seed = 81705
# Run 5: Seed = 17810
# Mean = 14.9350 | Max = 15.6611
#
# CONFIG: tournament|onepoint|reset|strong|random|elitism|S=15
#
# Seed list per run:
# Run 1: Seed = 26425
# Run 2: Seed = 75727
# Run 3: Seed = 8897
# Run 4: Seed = 59814
# Run 5: Seed = 51133
# Mean = 16.4301 | Max = 17.2453
#
# CONFIG: tournament|onepoint|reset|strong|random|rank|S=5
#
# Seed list per run:
# Run 1: Seed = 72649
# Run 2: Seed = 262
# Run 3: Seed = 56744
# Run 4: Seed = 57913
# Run 5: Seed = 24613
# Mean = 8.7248 | Max = 9.1984
#
# CONFIG: tournament|onepoint|reset|strong|random|rank|S=10
#
# Seed list per run:
# Run 1: Seed = 25213
# Run 2: Seed = 33697
# Run 3: Seed = 32818
# Run 4: Seed = 50296
# Run 5: Seed = 25649
# Mean = 13.1771 | Max = 14.4272
#
# CONFIG: tournament|onepoint|reset|strong|random|rank|S=15
#
# Seed list per run:
# Run 1: Seed = 19597
# Run 2: Seed = 98149
# Run 3: Seed = 9636
# Run 4: Seed = 75473
# Run 5: Seed = 81329
# Mean = 16.6406 | Max = 17.3499
#
# CONFIG: tournament|onepoint|reset|strong|heuristic|elitism|S=5
#
# Seed list per run:
# Run 1: Seed = 67128
# Run 2: Seed = 48074
# Run 3: Seed = 9179
# Run 4: Seed = 1641
# Run 5: Seed = 91354
# Mean = 10.5049 | Max = 11.3202
#
# CONFIG: tournament|onepoint|reset|strong|heuristic|elitism|S=10
#
# Seed list per run:
# Run 1: Seed = 42746
# Run 2: Seed = 98586
# Run 3: Seed = 67495
# Run 4: Seed = 43981
# Run 5: Seed = 86342
# Mean = 15.2954 | Max = 15.9298
#
# CONFIG: tournament|onepoint|reset|strong|heuristic|elitism|S=15
#
# Seed list per run:
# Run 1: Seed = 37148
# Run 2: Seed = 75277
# Run 3: Seed = 18030
# Run 4: Seed = 44890
# Run 5: Seed = 91752
# Mean = 16.5812 | Max = 17.3157
#
# CONFIG: tournament|onepoint|reset|strong|heuristic|rank|S=5
#
# Seed list per run:
# Run 1: Seed = 81530
# Run 2: Seed = 69356
# Run 3: Seed = 5023
# Run 4: Seed = 92836
# Run 5: Seed = 2489
# Mean = 10.1343 | Max = 10.8666
#
# CONFIG: tournament|onepoint|reset|strong|heuristic|rank|S=10
#
# Seed list per run:
# Run 1: Seed = 36097
# Run 2: Seed = 42057
# Run 3: Seed = 22109
# Run 4: Seed = 42429
# Run 5: Seed = 97143
# Mean = 15.2216 | Max = 16.3456
#
# CONFIG: tournament|onepoint|reset|strong|heuristic|rank|S=15
#
# Seed list per run:
# Run 1: Seed = 23011
# Run 2: Seed = 11864
# Run 3: Seed = 42629
# Run 4: Seed = 32168
# Run 5: Seed = 40426
# Mean = 16.3843 | Max = 17.3374
#
# CONFIG: tournament|uniform|shift|basic|random|elitism|S=5
#
# Seed list per run:
# Run 1: Seed = 67202
# Run 2: Seed = 88633
# Run 3: Seed = 77853
# Run 4: Seed = 39613
# Run 5: Seed = 3426
# Mean = 12.3136 | Max = 13.0422
#
# CONFIG: tournament|uniform|shift|basic|random|elitism|S=10
#
# Seed list per run:
# Run 1: Seed = 20951
# Run 2: Seed = 49498
# Run 3: Seed = 29973
# Run 4: Seed = 33324
# Run 5: Seed = 31652
# Mean = 17.6938 | Max = 18.8596
#
# CONFIG: tournament|uniform|shift|basic|random|elitism|S=15
#
# Seed list per run:
# Run 1: Seed = 59264
# Run 2: Seed = 2380
# Run 3: Seed = 99518
# Run 4: Seed = 81667
# Run 5: Seed = 16596
# Mean = 18.8752 | Max = 19.3494
#
# CONFIG: tournament|uniform|shift|basic|random|rank|S=5
#
# Seed list per run:
# Run 1: Seed = 15027
# Run 2: Seed = 47626
# Run 3: Seed = 27248
# Run 4: Seed = 26224
# Run 5: Seed = 67875
# Mean = 11.5076 | Max = 12.5558
#
# CONFIG: tournament|uniform|shift|basic|random|rank|S=10
#
# Seed list per run:
# Run 1: Seed = 68647
# Run 2: Seed = 97159
# Run 3: Seed = 97348
# Run 4: Seed = 64709
# Run 5: Seed = 28214
# Mean = 17.5171 | Max = 18.5997
#
# CONFIG: tournament|uniform|shift|basic|random|rank|S=15
#
# Seed list per run:
# Run 1: Seed = 9767
# Run 2: Seed = 167
# Run 3: Seed = 91931
# Run 4: Seed = 50120
# Run 5: Seed = 32042
# Mean = 18.8947 | Max = 19.2694
#
# CONFIG: tournament|uniform|shift|basic|heuristic|elitism|S=5
#
# Seed list per run:
# Run 1: Seed = 16757
# Run 2: Seed = 39733
# Run 3: Seed = 3008
# Run 4: Seed = 55776
# Run 5: Seed = 23060
# Mean = 12.0870 | Max = 12.4629
#
# CONFIG: tournament|uniform|shift|basic|heuristic|elitism|S=10
#
# Seed list per run:
# Run 1: Seed = 94577
# Run 2: Seed = 87214
# Run 3: Seed = 55807
# Run 4: Seed = 47934
# Run 5: Seed = 5389
# Mean = 18.4135 | Max = 19.0518
#
# CONFIG: tournament|uniform|shift|basic|heuristic|elitism|S=15
#
# Seed list per run:
# Run 1: Seed = 94898
# Run 2: Seed = 76792
# Run 3: Seed = 618
# Run 4: Seed = 32863
# Run 5: Seed = 89289
# Mean = 18.9570 | Max = 19.6987
#
# CONFIG: tournament|uniform|shift|basic|heuristic|rank|S=5
#
# Seed list per run:
# Run 1: Seed = 42373
# Run 2: Seed = 97174
# Run 3: Seed = 32616
# Run 4: Seed = 87044
# Run 5: Seed = 75553
# Mean = 11.9688 | Max = 12.8700
#
# CONFIG: tournament|uniform|shift|basic|heuristic|rank|S=10
#
# Seed list per run:
# Run 1: Seed = 9080
# Run 2: Seed = 97777
# Run 3: Seed = 28698
# Run 4: Seed = 31584
# Run 5: Seed = 43474
# Mean = 18.5877 | Max = 18.8993
#
# CONFIG: tournament|uniform|shift|basic|heuristic|rank|S=15
#
# Seed list per run:
# Run 1: Seed = 39562
# Run 2: Seed = 96467
# Run 3: Seed = 60666
# Run 4: Seed = 10806
# Run 5: Seed = 62182
# Mean = 18.7286 | Max = 19.9120
#
# CONFIG: tournament|uniform|shift|strong|random|elitism|S=5
#
# Seed list per run:
# Run 1: Seed = 25561
# Run 2: Seed = 35913
# Run 3: Seed = 54149
# Run 4: Seed = 42159
# Run 5: Seed = 27853
# Mean = 11.5110 | Max = 12.6007
#
# CONFIG: tournament|uniform|shift|strong|random|elitism|S=10
#
# Seed list per run:
# Run 1: Seed = 96836
# Run 2: Seed = 98112
# Run 3: Seed = 97310
# Run 4: Seed = 37461
# Run 5: Seed = 73133
# Mean = 16.4408 | Max = 18.4363
#
# CONFIG: tournament|uniform|shift|strong|random|elitism|S=15
#
# Seed list per run:
# Run 1: Seed = 74766
# Run 2: Seed = 29103
# Run 3: Seed = 436
# Run 4: Seed = 13685
# Run 5: Seed = 33659
# Mean = 17.9535 | Max = 18.8722
#
# CONFIG: tournament|uniform|shift|strong|random|rank|S=5
#
# Seed list per run:
# Run 1: Seed = 96630
# Run 2: Seed = 60066
# Run 3: Seed = 29896
# Run 4: Seed = 99028
# Run 5: Seed = 75090
# Mean = 10.5889 | Max = 11.9512
#
# CONFIG: tournament|uniform|shift|strong|random|rank|S=10
#
# Seed list per run:
# Run 1: Seed = 12011
# Run 2: Seed = 7791
# Run 3: Seed = 91324
# Run 4: Seed = 2863
# Run 5: Seed = 27271

# %% [markdown]
# ---
#
# # **7] Experimental Results Visualization**
#
# ---

# %%
def print_all_scores(results):

    print("\n" + "="*60)
    print("ALL FITNESS SCORES PER CONFIGURATION")
    print("="*60)

    for r in results:

        print("\n--------------------------------------")
        print(f"Algorithm : {r['algorithm']}")

        if r["algorithm"] != "DE":
            print(f"Selection : {r['selection']}")
            print(f"Crossover : {r['crossover']}")
            print(f"Mutation  : {r['mutation']}")
            print(f"Diversity : {r['diversity']}")

        print(f"Sensors   : {r['sensors']}")
        print(f"Mean      : {r['mean']:.4f}")
        print(f"Std       : {r['std']:.4f}")
        print(f"Max       : {r['max']:.4f}")

        # 👉 THIS is the full list of scores (if stored)
        if "scores" in r:
            print(f"\nAll Scores (runs):")
            print(r["scores"])

# %%
print_all_scores(results)
# Out:
# ============================================================
# ALL FITNESS SCORES PER CONFIGURATION
# ============================================================
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : shift
# Diversity : basic
# Sensors   : 5
# Mean      : 10.2522
# Std       : 0.9747
# Max       : 11.7424
#
# All Scores (runs):
# [np.float64(9.693527825179977), np.float64(9.377991781302644), np.float64(11.075469885497862), np.float64(11.742375025395535), np.float64(9.371396658822837)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : shift
# Diversity : basic
# Sensors   : 10
# Mean      : 16.3469
# Std       : 0.5190
# Max       : 17.0071
#
# All Scores (runs):
# [np.float64(15.819663414834281), np.float64(17.007137244192776), np.float64(15.79664864063633), np.float64(16.206780611028336), np.float64(16.904229843096214)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : shift
# Diversity : basic
# Sensors   : 15
# Mean      : 17.9578
# Std       : 0.8481
# Max       : 18.7317
#
# All Scores (runs):
# [np.float64(18.57800848710351), np.float64(17.473405960503342), np.float64(18.731663433619612), np.float64(16.511854522325137), np.float64(18.493868834259036)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : shift
# Diversity : basic
# Sensors   : 5
# Mean      : 11.9656
# Std       : 0.7365
# Max       : 12.8325
#
# All Scores (runs):
# [np.float64(12.832450276751413), np.float64(11.807152713102365), np.float64(12.083057456439027), np.float64(12.441787783125283), np.float64(10.663713371222723)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : shift
# Diversity : basic
# Sensors   : 10
# Mean      : 15.6963
# Std       : 1.0182
# Max       : 17.0235
#
# All Scores (runs):
# [np.float64(17.02347173168757), np.float64(14.37711918557791), np.float64(14.758533535425894), np.float64(16.59127782269135), np.float64(15.731210871108738)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : shift
# Diversity : basic
# Sensors   : 15
# Mean      : 17.9486
# Std       : 0.5634
# Max       : 18.6010
#
# All Scores (runs):
# [np.float64(17.332650265650933), np.float64(18.60098825559415), np.float64(18.3543906111537), np.float64(17.217813278173953), np.float64(18.237373771616248)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : shift
# Diversity : basic
# Sensors   : 5
# Mean      : 12.3253
# Std       : 0.1575
# Max       : 12.5725
#
# All Scores (runs):
# [np.float64(12.422450584365919), np.float64(12.305322099004457), np.float64(12.572524446706232), np.float64(12.18046276939713), np.float64(12.145956969466482)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : shift
# Diversity : basic
# Sensors   : 10
# Mean      : 17.4727
# Std       : 1.4276
# Max       : 18.9463
#
# All Scores (runs):
# [np.float64(18.1690495965271), np.float64(17.368721106406543), np.float64(18.08119210183524), np.float64(14.798269328217017), np.float64(18.946250946322195)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : shift
# Diversity : basic
# Sensors   : 15
# Mean      : 18.0699
# Std       : 0.6507
# Max       : 18.6016
#
# All Scores (runs):
# [np.float64(18.41122093175314), np.float64(17.96471155396764), np.float64(16.84567151828671), np.float64(18.526088565413602), np.float64(18.601602217057863)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : shift
# Diversity : basic
# Sensors   : 5
# Mean      : 12.4567
# Std       : 0.3334
# Max       : 12.8548
#
# All Scores (runs):
# [np.float64(12.005569112244533), np.float64(12.85480772715587), np.float64(12.774131058013333), np.float64(12.154352534090268), np.float64(12.494565618386677)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : shift
# Diversity : basic
# Sensors   : 10
# Mean      : 18.2468
# Std       : 0.4782
# Max       : 18.7586
#
# All Scores (runs):
# [np.float64(18.128305266026196), np.float64(18.75862360732068), np.float64(17.388329622109264), np.float64(18.58491797380042), np.float64(18.374029375880614)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : shift
# Diversity : basic
# Sensors   : 15
# Mean      : 18.1784
# Std       : 0.9484
# Max       : 19.2722
#
# All Scores (runs):
# [np.float64(18.817322481693623), np.float64(17.13896567463084), np.float64(19.272200034407756), np.float64(16.945370585338104), np.float64(18.71827865910753)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : shift
# Diversity : strong
# Sensors   : 5
# Mean      : 10.5433
# Std       : 0.4900
# Max       : 11.3148
#
# All Scores (runs):
# [np.float64(10.63185025876822), np.float64(9.801375263722372), np.float64(10.342810526006268), np.float64(10.625775743285178), np.float64(11.314791696694158)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : shift
# Diversity : strong
# Sensors   : 10
# Mean      : 14.7336
# Std       : 1.4802
# Max       : 16.5531
#
# All Scores (runs):
# [np.float64(13.175040699954762), np.float64(14.250002420094575), np.float64(13.270669982730983), np.float64(16.553122989297776), np.float64(16.41938531796098)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : shift
# Diversity : strong
# Sensors   : 15
# Mean      : 17.0365
# Std       : 0.8284
# Max       : 18.1770
#
# All Scores (runs):
# [np.float64(17.17018383547234), np.float64(16.701902696970876), np.float64(15.68374829595493), np.float64(18.176992378461286), np.float64(17.44955951054886)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : shift
# Diversity : strong
# Sensors   : 5
# Mean      : 10.4292
# Std       : 1.7830
# Max       : 12.6236
#
# All Scores (runs):
# [np.float64(11.961722357005714), np.float64(7.5378112958663746), np.float64(12.62361490002572), np.float64(10.117507261598666), np.float64(9.905239799021311)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : shift
# Diversity : strong
# Sensors   : 10
# Mean      : 14.4967
# Std       : 0.4470
# Max       : 15.3451
#
# All Scores (runs):
# [np.float64(14.088565852970914), np.float64(14.46037850121954), np.float64(14.172315814971677), np.float64(14.417211187364625), np.float64(15.345053397331208)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : shift
# Diversity : strong
# Sensors   : 15
# Mean      : 16.6395
# Std       : 0.9513
# Max       : 17.9896
#
# All Scores (runs):
# [np.float64(15.913798811125107), np.float64(17.467527334386336), np.float64(17.989642721312432), np.float64(15.446930796572586), np.float64(16.379740573150812)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : shift
# Diversity : strong
# Sensors   : 5
# Mean      : 12.3640
# Std       : 0.3292
# Max       : 12.7210
#
# All Scores (runs):
# [np.float64(12.482421410808213), np.float64(12.012403311082526), np.float64(11.935435678118077), np.float64(12.720950503519774), np.float64(12.668931239000287)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : shift
# Diversity : strong
# Sensors   : 10
# Mean      : 16.9115
# Std       : 0.6104
# Max       : 17.6860
#
# All Scores (runs):
# [np.float64(17.213478527577262), np.float64(17.686002750621668), np.float64(15.941576208855222), np.float64(17.194073543155103), np.float64(16.522427101066334)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : shift
# Diversity : strong
# Sensors   : 15
# Mean      : 17.0614
# Std       : 0.2040
# Max       : 17.2262
#
# All Scores (runs):
# [np.float64(16.663413155610918), np.float64(17.147055787809066), np.float64(17.226151259774344), np.float64(17.089138529244767), np.float64(17.181435084903807)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : shift
# Diversity : strong
# Sensors   : 5
# Mean      : 10.7588
# Std       : 0.7681
# Max       : 11.6046
#
# All Scores (runs):
# [np.float64(10.560241081080218), np.float64(10.854359860146124), np.float64(11.604581507382441), np.float64(9.410082166470577), np.float64(11.364621462973894)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : shift
# Diversity : strong
# Sensors   : 10
# Mean      : 16.8898
# Std       : 0.5006
# Max       : 17.7075
#
# All Scores (runs):
# [np.float64(16.505984232855592), np.float64(17.113904834173184), np.float64(16.85268045787362), np.float64(17.707525600310866), np.float64(16.269107076990302)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : shift
# Diversity : strong
# Sensors   : 15
# Mean      : 17.4861
# Std       : 0.5961
# Max       : 18.6092
#
# All Scores (runs):
# [np.float64(18.60919937251449), np.float64(17.56047886821124), np.float64(17.156647879786732), np.float64(17.163014344252257), np.float64(16.941033232292767)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : reset
# Diversity : basic
# Sensors   : 5
# Mean      : 10.7775
# Std       : 0.3174
# Max       : 11.1826
#
# All Scores (runs):
# [np.float64(10.424900145200084), np.float64(11.092235602440878), np.float64(11.1826406927098), np.float64(10.437803911956332), np.float64(10.749978492827982)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : reset
# Diversity : basic
# Sensors   : 10
# Mean      : 14.8092
# Std       : 0.5192
# Max       : 15.2893
#
# All Scores (runs):
# [np.float64(15.28415381768213), np.float64(13.900270994217653), np.float64(14.965331853047262), np.float64(15.289326724214197), np.float64(14.606703493944318)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : reset
# Diversity : basic
# Sensors   : 15
# Mean      : 17.0358
# Std       : 0.1920
# Max       : 17.3051
#
# All Scores (runs):
# [np.float64(16.721453574046453), np.float64(17.139079724197263), np.float64(17.024365607023526), np.float64(16.98883625884956), np.float64(17.305114850682)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : reset
# Diversity : basic
# Sensors   : 5
# Mean      : 10.7892
# Std       : 0.5690
# Max       : 11.4239
#
# All Scores (runs):
# [np.float64(11.391114494031099), np.float64(11.423864096767877), np.float64(9.898180457799429), np.float64(10.627526254455773), np.float64(10.605544374795501)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : reset
# Diversity : basic
# Sensors   : 10
# Mean      : 15.6419
# Std       : 0.8598
# Max       : 16.8513
#
# All Scores (runs):
# [np.float64(16.85132612749403), np.float64(14.830566086628378), np.float64(15.011731025018491), np.float64(14.999175013579826), np.float64(16.516590466572758)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : reset
# Diversity : basic
# Sensors   : 15
# Mean      : 17.1028
# Std       : 0.0820
# Max       : 17.2022
#
# All Scores (runs):
# [np.float64(16.98552000485714), np.float64(17.202221045186548), np.float64(17.153289879233625), np.float64(17.027726314600628), np.float64(17.145114111427297)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : reset
# Diversity : basic
# Sensors   : 5
# Mean      : 11.1162
# Std       : 0.4056
# Max       : 11.7272
#
# All Scores (runs):
# [np.float64(10.468896286200033), np.float64(11.727230865388275), np.float64(10.992245544572846), np.float64(11.227213098994968), np.float64(11.16549517184695)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : reset
# Diversity : basic
# Sensors   : 10
# Mean      : 16.4394
# Std       : 0.9578
# Max       : 17.8698
#
# All Scores (runs):
# [np.float64(16.278954075739577), np.float64(15.964337417684005), np.float64(17.869811946354712), np.float64(15.048626832063873), np.float64(17.035100349925933)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : reset
# Diversity : basic
# Sensors   : 15
# Mean      : 17.2854
# Std       : 0.1394
# Max       : 17.4756
#
# All Scores (runs):
# [np.float64(17.23675662293757), np.float64(17.396810869515058), np.float64(17.242893698595473), np.float64(17.475566241257102), np.float64(17.07479428383562)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : reset
# Diversity : basic
# Sensors   : 5
# Mean      : 10.8341
# Std       : 0.1916
# Max       : 11.0606
#
# All Scores (runs):
# [np.float64(10.710698365971513), np.float64(11.018089610815673), np.float64(10.835358657088209), np.float64(10.545748825980022), np.float64(11.060595773652615)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : reset
# Diversity : basic
# Sensors   : 10
# Mean      : 15.7572
# Std       : 0.6144
# Max       : 16.6656
#
# All Scores (runs):
# [np.float64(15.124537703975761), np.float64(15.739214244848133), np.float64(15.06767099595693), np.float64(16.188955345498005), np.float64(16.665567121602717)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : reset
# Diversity : basic
# Sensors   : 15
# Mean      : 16.9520
# Std       : 0.5899
# Max       : 17.9007
#
# All Scores (runs):
# [np.float64(16.607243414214636), np.float64(16.641540703292424), np.float64(17.900702283291803), np.float64(16.265979168874768), np.float64(17.344497035173013)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : reset
# Diversity : strong
# Sensors   : 5
# Mean      : 9.9858
# Std       : 0.5024
# Max       : 10.6223
#
# All Scores (runs):
# [np.float64(9.22276886949169), np.float64(10.622250059488671), np.float64(10.352658619945093), np.float64(9.62969127873869), np.float64(10.10142315612666)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : reset
# Diversity : strong
# Sensors   : 10
# Mean      : 14.0469
# Std       : 0.6772
# Max       : 15.3054
#
# All Scores (runs):
# [np.float64(13.69433392240052), np.float64(15.305382337901444), np.float64(14.200381597754923), np.float64(13.519959372119978), np.float64(13.51428336934973)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : reset
# Diversity : strong
# Sensors   : 15
# Mean      : 15.8838
# Std       : 0.7674
# Max       : 16.9315
#
# All Scores (runs):
# [np.float64(16.386610746444433), np.float64(16.93146737915723), np.float64(15.214009150127714), np.float64(16.058992888674823), np.float64(14.828122810846372)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : reset
# Diversity : strong
# Sensors   : 5
# Mean      : 9.5876
# Std       : 0.2985
# Max       : 9.9664
#
# All Scores (runs):
# [np.float64(9.874314518631753), np.float64(9.459514241737674), np.float64(9.966422510764918), np.float64(9.490455846139346), np.float64(9.147323029728607)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : reset
# Diversity : strong
# Sensors   : 10
# Mean      : 13.7761
# Std       : 1.0344
# Max       : 15.4809
#
# All Scores (runs):
# [np.float64(13.39200290292301), np.float64(13.243046352233739), np.float64(14.304709864901264), np.float64(15.480925925504373), np.float64(12.459898770130133)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : reset
# Diversity : strong
# Sensors   : 15
# Mean      : 15.7718
# Std       : 0.4887
# Max       : 16.3291
#
# All Scores (runs):
# [np.float64(16.035490147806357), np.float64(16.329091570902825), np.float64(15.29332784443327), np.float64(15.087628241037145), np.float64(16.113658750159725)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : reset
# Diversity : strong
# Sensors   : 5
# Mean      : 10.6986
# Std       : 0.7307
# Max       : 11.8003
#
# All Scores (runs):
# [np.float64(9.686774617116358), np.float64(10.177043823291594), np.float64(11.096800137691197), np.float64(11.80033342140772), np.float64(10.732251972215115)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : reset
# Diversity : strong
# Sensors   : 10
# Mean      : 14.7475
# Std       : 0.4014
# Max       : 15.2257
#
# All Scores (runs):
# [np.float64(14.934575601202319), np.float64(15.225688458545793), np.float64(14.425620350390002), np.float64(14.140433527580305), np.float64(15.011362022333183)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : reset
# Diversity : strong
# Sensors   : 15
# Mean      : 17.2212
# Std       : 0.5223
# Max       : 18.1867
#
# All Scores (runs):
# [np.float64(17.230699032074174), np.float64(16.820632016515916), np.float64(17.16459471343232), np.float64(18.186679049422352), np.float64(16.70355372060696)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : reset
# Diversity : strong
# Sensors   : 5
# Mean      : 9.9892
# Std       : 0.7669
# Max       : 11.3504
#
# All Scores (runs):
# [np.float64(10.324428019276203), np.float64(9.422537190101062), np.float64(11.3504322364609), np.float64(9.33549767416686), np.float64(9.512972976330621)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : reset
# Diversity : strong
# Sensors   : 10
# Mean      : 14.8645
# Std       : 0.5785
# Max       : 15.5941
#
# All Scores (runs):
# [np.float64(15.245853326295524), np.float64(15.594122086963564), np.float64(14.31317978347745), np.float64(15.10198874801846), np.float64(14.06758689779014)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : onepoint
# Mutation  : reset
# Diversity : strong
# Sensors   : 15
# Mean      : 17.0069
# Std       : 0.5992
# Max       : 17.7249
#
# All Scores (runs):
# [np.float64(17.724869705930754), np.float64(15.913350316724468), np.float64(17.058528838027343), np.float64(17.288340617803325), np.float64(17.049285961446273)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : shift
# Diversity : basic
# Sensors   : 5
# Mean      : 11.1354
# Std       : 0.3581
# Max       : 11.7172
#
# All Scores (runs):
# [np.float64(10.966311972303556), np.float64(11.02313362657366), np.float64(11.313995402969498), np.float64(11.717242014898869), np.float64(10.656179986404444)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : shift
# Diversity : basic
# Sensors   : 10
# Mean      : 17.0345
# Std       : 0.8201
# Max       : 18.0319
#
# All Scores (runs):
# [np.float64(15.965283921340612), np.float64(18.031875750769633), np.float64(16.923991487182768), np.float64(16.352198991705418), np.float64(17.89905744148312)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : shift
# Diversity : basic
# Sensors   : 15
# Mean      : 18.4740
# Std       : 0.7639
# Max       : 19.3788
#
# All Scores (runs):
# [np.float64(18.42829582189021), np.float64(18.114663127525372), np.float64(19.37875742237957), np.float64(17.264318494569043), np.float64(19.184169396978085)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : shift
# Diversity : basic
# Sensors   : 5
# Mean      : 11.0017
# Std       : 0.5325
# Max       : 11.6584
#
# All Scores (runs):
# [np.float64(11.658352530951424), np.float64(11.172959556737515), np.float64(10.742353579141396), np.float64(10.113964919257155), np.float64(11.320988321268018)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : shift
# Diversity : basic
# Sensors   : 10
# Mean      : 16.0926
# Std       : 1.1885
# Max       : 17.8101
#
# All Scores (runs):
# [np.float64(17.81005430376295), np.float64(17.044335768332385), np.float64(15.039205502607057), np.float64(15.913882493028755), np.float64(14.655359829871474)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : shift
# Diversity : basic
# Sensors   : 15
# Mean      : 17.7489
# Std       : 1.0768
# Max       : 19.0521
#
# All Scores (runs):
# [np.float64(19.052111370661606), np.float64(18.63249629641979), np.float64(15.957683171710727), np.float64(17.676895522881647), np.float64(17.425114500864687)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : shift
# Diversity : basic
# Sensors   : 5
# Mean      : 12.0394
# Std       : 0.9845
# Max       : 12.7504
#
# All Scores (runs):
# [np.float64(12.660618224242883), np.float64(12.018382894258302), np.float64(12.62781113412969), np.float64(10.139967917510742), np.float64(12.750404080059413)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : shift
# Diversity : basic
# Sensors   : 10
# Mean      : 17.9631
# Std       : 0.4334
# Max       : 18.4104
#
# All Scores (runs):
# [np.float64(18.410369727537095), np.float64(17.534068959738907), np.float64(17.367734706269594), np.float64(18.121491013073474), np.float64(18.381810297713667)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : shift
# Diversity : basic
# Sensors   : 15
# Mean      : 18.5298
# Std       : 0.5457
# Max       : 19.1631
#
# All Scores (runs):
# [np.float64(18.078991625266035), np.float64(17.71073444148803), np.float64(18.773024940237367), np.float64(19.163072848845797), np.float64(18.923140755115583)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : shift
# Diversity : basic
# Sensors   : 5
# Mean      : 12.1047
# Std       : 0.3539
# Max       : 12.6390
#
# All Scores (runs):
# [np.float64(12.072564792200588), np.float64(11.531809929441376), np.float64(12.072564792200588), np.float64(12.207333865003926), np.float64(12.639031058798803)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : shift
# Diversity : basic
# Sensors   : 10
# Mean      : 18.0348
# Std       : 0.9682
# Max       : 19.0113
#
# All Scores (runs):
# [np.float64(18.159469540471058), np.float64(18.966930635387936), np.float64(19.011292715103497), np.float64(17.643787965316413), np.float64(16.39275204253534)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : shift
# Diversity : basic
# Sensors   : 15
# Mean      : 18.8093
# Std       : 0.4750
# Max       : 19.4193
#
# All Scores (runs):
# [np.float64(18.081349655054463), np.float64(18.9795286523761), np.float64(19.09608321416022), np.float64(18.47014524438421), np.float64(19.419277002905414)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : shift
# Diversity : strong
# Sensors   : 5
# Mean      : 11.5469
# Std       : 0.6537
# Max       : 12.2254
#
# All Scores (runs):
# [np.float64(12.175647322914664), np.float64(12.225357556993181), np.float64(11.680359526113115), np.float64(11.162273205854135), np.float64(10.490771692286701)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : shift
# Diversity : strong
# Sensors   : 10
# Mean      : 16.6559
# Std       : 0.7115
# Max       : 17.9077
#
# All Scores (runs):
# [np.float64(16.61120634152703), np.float64(17.907655276074415), np.float64(16.46482719064549), np.float64(15.695299170796764), np.float64(16.600745862664823)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : shift
# Diversity : strong
# Sensors   : 15
# Mean      : 18.1872
# Std       : 0.5658
# Max       : 19.0175
#
# All Scores (runs):
# [np.float64(18.253458955340363), np.float64(19.017489307553845), np.float64(17.24490110385546), np.float64(18.115808553009597), np.float64(18.30418358015005)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : shift
# Diversity : strong
# Sensors   : 5
# Mean      : 11.4005
# Std       : 0.7643
# Max       : 12.1765
#
# All Scores (runs):
# [np.float64(12.176524323734172), np.float64(10.351466198774764), np.float64(11.973263382241226), np.float64(10.600607826995114), np.float64(11.900849555167886)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : shift
# Diversity : strong
# Sensors   : 10
# Mean      : 15.7064
# Std       : 0.9935
# Max       : 17.0832
#
# All Scores (runs):
# [np.float64(16.095935504056776), np.float64(17.083222320436175), np.float64(16.173654540825257), np.float64(14.293426772191774), np.float64(14.885773865671132)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : shift
# Diversity : strong
# Sensors   : 15
# Mean      : 17.2805
# Std       : 0.7688
# Max       : 17.9580
#
# All Scores (runs):
# [np.float64(16.146499861939596), np.float64(17.958047080634593), np.float64(17.860053136874118), np.float64(16.56080544707507), np.float64(17.877324584016808)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : shift
# Diversity : strong
# Sensors   : 5
# Mean      : 11.3460
# Std       : 0.6038
# Max       : 12.2436
#
# All Scores (runs):
# [np.float64(10.585740014674858), np.float64(11.794737020637061), np.float64(12.243626689686335), np.float64(10.871341362611965), np.float64(11.234715331669728)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : shift
# Diversity : strong
# Sensors   : 10
# Mean      : 17.1982
# Std       : 0.5861
# Max       : 18.3527
#
# All Scores (runs):
# [np.float64(17.092201785773646), np.float64(18.352728257668616), np.float64(16.82756546651436), np.float64(16.916129900227002), np.float64(16.802390430509735)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : shift
# Diversity : strong
# Sensors   : 15
# Mean      : 17.7712
# Std       : 0.2948
# Max       : 18.1373
#
# All Scores (runs):
# [np.float64(17.898864995945598), np.float64(17.916077293565166), np.float64(17.62401533879011), np.float64(18.137254928404754), np.float64(17.279812316154583)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : shift
# Diversity : strong
# Sensors   : 5
# Mean      : 11.5677
# Std       : 0.9027
# Max       : 12.5790
#
# All Scores (runs):
# [np.float64(11.87343715370669), np.float64(12.57902049262627), np.float64(10.475404276038503), np.float64(12.388017406775965), np.float64(10.522687900755493)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : shift
# Diversity : strong
# Sensors   : 10
# Mean      : 17.6030
# Std       : 0.5072
# Max       : 18.2689
#
# All Scores (runs):
# [np.float64(18.268878815685166), np.float64(17.478289760688153), np.float64(17.449277847048428), np.float64(18.012755959151928), np.float64(16.805637513795144)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : shift
# Diversity : strong
# Sensors   : 15
# Mean      : 17.7126
# Std       : 0.6960
# Max       : 18.7113
#
# All Scores (runs):
# [np.float64(16.800114243265472), np.float64(18.22802931529246), np.float64(17.14209635428306), np.float64(17.68162643486299), np.float64(18.711276128009033)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : reset
# Diversity : basic
# Sensors   : 5
# Mean      : 10.7883
# Std       : 0.6863
# Max       : 11.9927
#
# All Scores (runs):
# [np.float64(9.894124462297981), np.float64(10.659626811461958), np.float64(11.992650248478219), np.float64(10.507546845188921), np.float64(10.887580535544734)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : reset
# Diversity : basic
# Sensors   : 10
# Mean      : 15.7436
# Std       : 0.5055
# Max       : 16.3463
#
# All Scores (runs):
# [np.float64(15.937393685528255), np.float64(14.900325517308582), np.float64(15.480362754956696), np.float64(16.05367356510955), np.float64(16.34634277519729)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : reset
# Diversity : basic
# Sensors   : 15
# Mean      : 17.4359
# Std       : 0.3708
# Max       : 18.1233
#
# All Scores (runs):
# [np.float64(18.123270053725342), np.float64(17.005208736612712), np.float64(17.409007246886024), np.float64(17.356640543354853), np.float64(17.285587483960157)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : reset
# Diversity : basic
# Sensors   : 5
# Mean      : 10.4727
# Std       : 0.4650
# Max       : 11.0005
#
# All Scores (runs):
# [np.float64(10.94069266788116), np.float64(10.23233051882507), np.float64(11.000540447045223), np.float64(9.748451811930401), np.float64(10.441331129680947)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : reset
# Diversity : basic
# Sensors   : 10
# Mean      : 15.3168
# Std       : 1.1951
# Max       : 16.9558
#
# All Scores (runs):
# [np.float64(16.955769331889357), np.float64(15.389788693099607), np.float64(15.317700159211345), np.float64(15.681541771616548), np.float64(13.23921460051588)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : reset
# Diversity : basic
# Sensors   : 15
# Mean      : 16.6901
# Std       : 0.6955
# Max       : 17.5042
#
# All Scores (runs):
# [np.float64(17.18683039464771), np.float64(17.504208728275124), np.float64(16.039470255831805), np.float64(15.70128030330633), np.float64(17.018830986485966)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : reset
# Diversity : basic
# Sensors   : 5
# Mean      : 10.8349
# Std       : 0.7861
# Max       : 12.0986
#
# All Scores (runs):
# [np.float64(12.09862070339651), np.float64(10.907810446151126), np.float64(11.14530372955533), np.float64(9.880190691128714), np.float64(10.142595748247633)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : reset
# Diversity : basic
# Sensors   : 10
# Mean      : 15.6488
# Std       : 0.3478
# Max       : 16.2600
#
# All Scores (runs):
# [np.float64(15.659888744098941), np.float64(15.701346969505416), np.float64(15.328078301672901), np.float64(16.25996946228596), np.float64(15.294686200184426)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : reset
# Diversity : basic
# Sensors   : 15
# Mean      : 16.9815
# Std       : 0.6581
# Max       : 17.8339
#
# All Scores (runs):
# [np.float64(17.833900323137307), np.float64(16.26175215995122), np.float64(17.6990480145757), np.float64(16.705460121093946), np.float64(16.407470994541118)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : reset
# Diversity : basic
# Sensors   : 5
# Mean      : 10.6040
# Std       : 0.6533
# Max       : 11.5933
#
# All Scores (runs):
# [np.float64(10.314017674687737), np.float64(10.82656353965197), np.float64(9.59675452081938), np.float64(11.593299758601834), np.float64(10.68950549644164)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : reset
# Diversity : basic
# Sensors   : 10
# Mean      : 15.5525
# Std       : 0.5920
# Max       : 16.4484
#
# All Scores (runs):
# [np.float64(15.032229489389453), np.float64(14.813630511687697), np.float64(15.550823039807335), np.float64(15.917275278753484), np.float64(16.44837266328278)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : reset
# Diversity : basic
# Sensors   : 15
# Mean      : 17.0675
# Std       : 0.3157
# Max       : 17.6111
#
# All Scores (runs):
# [np.float64(17.61106774333779), np.float64(17.14955894632399), np.float64(17.026045486260422), np.float64(16.884037690642757), np.float64(16.66668284337238)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : reset
# Diversity : strong
# Sensors   : 5
# Mean      : 9.9949
# Std       : 0.7063
# Max       : 11.2703
#
# All Scores (runs):
# [np.float64(9.281862135224904), np.float64(9.91779957234926), np.float64(11.270264899453611), np.float64(10.095305830402033), np.float64(9.409213696822428)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : reset
# Diversity : strong
# Sensors   : 10
# Mean      : 15.2902
# Std       : 0.6617
# Max       : 16.2408
#
# All Scores (runs):
# [np.float64(15.544189854007621), np.float64(14.82959995709515), np.float64(14.313191106792049), np.float64(15.52341561909195), np.float64(16.240792941188914)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : reset
# Diversity : strong
# Sensors   : 15
# Mean      : 16.6070
# Std       : 0.6520
# Max       : 17.7193
#
# All Scores (runs):
# [np.float64(15.964067154928298), np.float64(16.883841155106815), np.float64(16.47923633558392), np.float64(15.988711999975639), np.float64(17.71927337247023)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : reset
# Diversity : strong
# Sensors   : 5
# Mean      : 9.4084
# Std       : 0.8530
# Max       : 10.5404
#
# All Scores (runs):
# [np.float64(9.601546837367426), np.float64(10.5404047732191), np.float64(8.363521837631724), np.float64(10.03903573802531), np.float64(8.497383675155985)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : reset
# Diversity : strong
# Sensors   : 10
# Mean      : 14.1983
# Std       : 0.6954
# Max       : 15.0982
#
# All Scores (runs):
# [np.float64(13.044578379614354), np.float64(13.992130974020675), np.float64(14.68194164450194), np.float64(15.0981694860353), np.float64(14.174917879489279)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : reset
# Diversity : strong
# Sensors   : 15
# Mean      : 16.7474
# Std       : 0.5799
# Max       : 17.3814
#
# All Scores (runs):
# [np.float64(16.801923443030454), np.float64(16.55807633621002), np.float64(17.24493213532349), np.float64(15.7508935939041), np.float64(17.38140587999574)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : reset
# Diversity : strong
# Sensors   : 5
# Mean      : 10.5812
# Std       : 0.7603
# Max       : 11.7529
#
# All Scores (runs):
# [np.float64(9.351031190241343), np.float64(10.613953924351577), np.float64(10.6285279840077), np.float64(10.55965729477556), np.float64(11.752938503285206)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : reset
# Diversity : strong
# Sensors   : 10
# Mean      : 15.0244
# Std       : 0.7648
# Max       : 16.3238
#
# All Scores (runs):
# [np.float64(14.944681069148137), np.float64(15.316688225875069), np.float64(16.32384304179116), np.float64(14.292691772137928), np.float64(14.244028448400693)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : reset
# Diversity : strong
# Sensors   : 15
# Mean      : 16.8675
# Std       : 0.5227
# Max       : 17.6066
#
# All Scores (runs):
# [np.float64(16.78342956872834), np.float64(15.981068986060647), np.float64(17.606559768315254), np.float64(16.971915569346866), np.float64(16.99428314928851)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : reset
# Diversity : strong
# Sensors   : 5
# Mean      : 9.8170
# Std       : 0.5140
# Max       : 10.5939
#
# All Scores (runs):
# [np.float64(9.002690282347462), np.float64(9.65005815131737), np.float64(9.865897998485234), np.float64(9.972270184662698), np.float64(10.593938089582435)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : reset
# Diversity : strong
# Sensors   : 10
# Mean      : 14.9123
# Std       : 0.6798
# Max       : 15.6353
#
# All Scores (runs):
# [np.float64(15.314717043571767), np.float64(14.029796035739098), np.float64(15.430525108022895), np.float64(14.15140988931735), np.float64(15.635288934222388)]
#
# --------------------------------------
# Algorithm : GA
# Selection : tournament
# Crossover : uniform
# Mutation  : reset
# Diversity : strong
# Sensors   : 15
# Mean      : 16.7392
# Std       : 0.9046
# Max       : 17.4597
#
# All Scores (runs):
# [np.float64(17.3741689594747), np.float64(17.024683258469608), np.float64(16.85186971503662), np.float64(14.98573946803105), np.float64(17.459734251888193)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : shift
# Diversity : basic
# Sensors   : 5
# Mean      : 10.5444
# Std       : 0.8907
# Max       : 11.9821
#
# All Scores (runs):
# [np.float64(10.056967999314422), np.float64(11.18003804358196), np.float64(9.747627630173918), np.float64(11.98210614167104), np.float64(9.755133646938193)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : shift
# Diversity : basic
# Sensors   : 10
# Mean      : 14.9767
# Std       : 1.4921
# Max       : 16.8727
#
# All Scores (runs):
# [np.float64(13.339039952368177), np.float64(16.87267807635824), np.float64(13.283472691427606), np.float64(15.001684913789568), np.float64(16.386425769434773)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : shift
# Diversity : basic
# Sensors   : 15
# Mean      : 16.7688
# Std       : 0.8541
# Max       : 17.6230
#
# All Scores (runs):
# [np.float64(17.399768981429894), np.float64(16.80962442674903), np.float64(16.828356036093663), np.float64(15.183030758304907), np.float64(17.62304938052801)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : shift
# Diversity : basic
# Sensors   : 5
# Mean      : 10.2791
# Std       : 0.9060
# Max       : 11.6513
#
# All Scores (runs):
# [np.float64(10.57910729621872), np.float64(8.836450326911423), np.float64(10.05574175295274), np.float64(10.272869815341732), np.float64(11.65129942835417)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : shift
# Diversity : basic
# Sensors   : 10
# Mean      : 15.5274
# Std       : 1.2612
# Max       : 17.9666
#
# All Scores (runs):
# [np.float64(14.343425167572844), np.float64(17.966580238837665), np.float64(15.141155065776516), np.float64(14.899074719710953), np.float64(15.286623876485013)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : shift
# Diversity : basic
# Sensors   : 15
# Mean      : 17.1713
# Std       : 0.5041
# Max       : 17.9977
#
# All Scores (runs):
# [np.float64(16.50430602032682), np.float64(17.99771018101839), np.float64(17.269595489013362), np.float64(17.266264333161704), np.float64(16.818729949224654)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : shift
# Diversity : basic
# Sensors   : 5
# Mean      : 12.0407
# Std       : 0.6670
# Max       : 12.9781
#
# All Scores (runs):
# [np.float64(11.891526434122476), np.float64(11.912166965554661), np.float64(12.978145247942717), np.float64(12.44893083058673), np.float64(10.972815433970656)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : shift
# Diversity : basic
# Sensors   : 10
# Mean      : 16.4738
# Std       : 1.0993
# Max       : 17.9933
#
# All Scores (runs):
# [np.float64(14.588335009672345), np.float64(16.75659980710389), np.float64(16.732877216498377), np.float64(17.993292201026346), np.float64(16.297935775734043)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : shift
# Diversity : basic
# Sensors   : 15
# Mean      : 17.6150
# Std       : 0.3727
# Max       : 18.1813
#
# All Scores (runs):
# [np.float64(17.2272919284904), np.float64(17.847271890186644), np.float64(17.616026045064196), np.float64(18.18129484583802), np.float64(17.20332487922982)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : shift
# Diversity : basic
# Sensors   : 5
# Mean      : 12.0351
# Std       : 0.8157
# Max       : 12.9112
#
# All Scores (runs):
# [np.float64(12.725189017580874), np.float64(11.026946712565184), np.float64(12.911194390770731), np.float64(11.081039118874832), np.float64(12.430962633109022)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : shift
# Diversity : basic
# Sensors   : 10
# Mean      : 16.7241
# Std       : 0.6571
# Max       : 17.7358
#
# All Scores (runs):
# [np.float64(17.008858559590575), np.float64(15.871196255760314), np.float64(16.16441961271465), np.float64(17.73584759374458), np.float64(16.8400249531833)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : shift
# Diversity : basic
# Sensors   : 15
# Mean      : 18.3156
# Std       : 0.4328
# Max       : 19.0778
#
# All Scores (runs):
# [np.float64(19.077755621096784), np.float64(18.342822975617793), np.float64(17.82067837335764), np.float64(17.985558630788116), np.float64(18.351091896473683)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : shift
# Diversity : strong
# Sensors   : 5
# Mean      : 9.5927
# Std       : 1.3593
# Max       : 11.3007
#
# All Scores (runs):
# [np.float64(9.15660325269716), np.float64(11.048826781128815), np.float64(11.300677371877788), np.float64(8.609454264746626), np.float64(7.847794090324392)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : shift
# Diversity : strong
# Sensors   : 10
# Mean      : 15.0706
# Std       : 1.1404
# Max       : 16.9452
#
# All Scores (runs):
# [np.float64(15.80430310313528), np.float64(16.945187506454147), np.float64(14.157939427514854), np.float64(13.923457955782174), np.float64(14.522209107187571)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : shift
# Diversity : strong
# Sensors   : 15
# Mean      : 16.5558
# Std       : 0.6805
# Max       : 17.4431
#
# All Scores (runs):
# [np.float64(16.84122740832555), np.float64(16.949488282985385), np.float64(15.952296896053502), np.float64(17.443092770923574), np.float64(15.592679390074103)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : shift
# Diversity : strong
# Sensors   : 5
# Mean      : 10.3297
# Std       : 1.0009
# Max       : 11.4966
#
# All Scores (runs):
# [np.float64(10.383629311336424), np.float64(10.23450706813227), np.float64(8.541746268896773), np.float64(10.992173854377905), np.float64(11.496630436621654)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : shift
# Diversity : strong
# Sensors   : 10
# Mean      : 14.5055
# Std       : 1.3089
# Max       : 15.5324
#
# All Scores (runs):
# [np.float64(12.019207482618938), np.float64(15.46336402848569), np.float64(15.13431503649312), np.float64(15.532448387264848), np.float64(14.377921070888952)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : shift
# Diversity : strong
# Sensors   : 15
# Mean      : 16.3255
# Std       : 0.8656
# Max       : 17.7063
#
# All Scores (runs):
# [np.float64(15.452123388275016), np.float64(15.928761631256553), np.float64(16.94604192412674), np.float64(15.594499069735125), np.float64(17.706314011050736)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : shift
# Diversity : strong
# Sensors   : 5
# Mean      : 11.8629
# Std       : 0.6210
# Max       : 12.4177
#
# All Scores (runs):
# [np.float64(12.403719382233975), np.float64(12.225840493474678), np.float64(11.390743895761803), np.float64(12.417683426616284), np.float64(10.87649911199067)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : shift
# Diversity : strong
# Sensors   : 10
# Mean      : 16.2060
# Std       : 0.7818
# Max       : 17.1203
#
# All Scores (runs):
# [np.float64(14.976527319594691), np.float64(17.120321069064143), np.float64(16.93493356513547), np.float64(16.213567419178553), np.float64(15.78474712618079)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : shift
# Diversity : strong
# Sensors   : 15
# Mean      : 17.0667
# Std       : 0.5646
# Max       : 17.7483
#
# All Scores (runs):
# [np.float64(17.262711962884353), np.float64(16.476331820058512), np.float64(17.74827808034957), np.float64(17.515114815545235), np.float64(16.331065877829214)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : shift
# Diversity : strong
# Sensors   : 5
# Mean      : 11.5444
# Std       : 0.7977
# Max       : 12.4330
#
# All Scores (runs):
# [np.float64(10.25251770694594), np.float64(12.433029299734732), np.float64(11.116213298471862), np.float64(12.271622671828316), np.float64(11.648793790092117)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : shift
# Diversity : strong
# Sensors   : 10
# Mean      : 16.3642
# Std       : 0.6322
# Max       : 17.6069
#
# All Scores (runs):
# [np.float64(16.016869900910045), np.float64(17.606917358919098), np.float64(15.901093187524966), np.float64(16.03516706209724), np.float64(16.261007246062192)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : shift
# Diversity : strong
# Sensors   : 15
# Mean      : 17.1618
# Std       : 0.6090
# Max       : 18.0808
#
# All Scores (runs):
# [np.float64(17.685388747902177), np.float64(18.0808442910437), np.float64(16.79434086257516), np.float64(16.73067365640587), np.float64(16.51772265863269)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : reset
# Diversity : basic
# Sensors   : 5
# Mean      : 10.0356
# Std       : 0.6662
# Max       : 11.0985
#
# All Scores (runs):
# [np.float64(9.200503827231433), np.float64(11.09846308192949), np.float64(10.17122665451662), np.float64(10.24595429685302), np.float64(9.461793891682255)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : reset
# Diversity : basic
# Sensors   : 10
# Mean      : 14.4010
# Std       : 1.3339
# Max       : 16.0453
#
# All Scores (runs):
# [np.float64(12.329337582588646), np.float64(14.241573298633826), np.float64(16.045259863080734), np.float64(15.617237475408736), np.float64(13.771573999794212)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : reset
# Diversity : basic
# Sensors   : 15
# Mean      : 15.6899
# Std       : 0.9462
# Max       : 16.7406
#
# All Scores (runs):
# [np.float64(15.091307037616712), np.float64(16.241556263156095), np.float64(16.740572943198416), np.float64(16.238195402362603), np.float64(14.137627413129161)]
#
# --------------------------------------
# Algorithm : GA
# Selection : roulette
# Crossover : onepoint
# Mutation  : reset
# Diversity : basic
# Sensors   : 5
# Mean      : 10.2065
# ...
#
# All Scores (runs):
# [np.float64(12.692086617777107), np.float64(12.661129517714084), np.float64(12.082297312154235), np.float64(12.645211984533951), np.float64(12.283069352228999)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : shift
# Diversity : basic
# Sensors   : 10
# Mean      : 18.1124
# Std       : 0.5432
# Max       : 18.8044
#
# All Scores (runs):
# [np.float64(18.44395300048962), np.float64(17.1740098082993), np.float64(18.103738193020693), np.float64(18.804436765382665), np.float64(18.035908673283775)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : shift
# Diversity : basic
# Sensors   : 15
# Mean      : 18.0453
# Std       : 0.5272
# Max       : 19.0146
#
# All Scores (runs):
# [np.float64(17.71017636755131), np.float64(19.014627060629564), np.float64(17.493019989159276), np.float64(18.12607350217873), np.float64(17.882655874659633)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : shift
# Diversity : basic
# Sensors   : 5
# Mean      : 12.3147
# Std       : 0.3901
# Max       : 12.6843
#
# All Scores (runs):
# [np.float64(12.629346100976335), np.float64(11.85683051318287), np.float64(11.820611187488842), np.float64(12.582302027236713), np.float64(12.684284896490905)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : shift
# Diversity : basic
# Sensors   : 10
# Mean      : 18.4523
# Std       : 0.2664
# Max       : 18.7659
#
# All Scores (runs):
# [np.float64(18.400260827447514), np.float64(18.765920127879834), np.float64(18.595509101348338), np.float64(17.97472489757674), np.float64(18.52504308575833)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : shift
# Diversity : basic
# Sensors   : 15
# Mean      : 18.5851
# Std       : 0.4037
# Max       : 19.3224
#
# All Scores (runs):
# [np.float64(18.548775556868083), np.float64(19.32236314762805), np.float64(18.215158518839075), np.float64(18.617141779082004), np.float64(18.22190114665942)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : shift
# Diversity : strong
# Sensors   : 5
# Mean      : 12.1214
# Std       : 0.4420
# Max       : 12.7407
#
# All Scores (runs):
# [np.float64(11.542201800236603), np.float64(12.740671560105767), np.float64(12.504173005222151), np.float64(11.805193399066239), np.float64(12.01493655875186)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : shift
# Diversity : strong
# Sensors   : 10
# Mean      : 17.1180
# Std       : 0.5185
# Max       : 17.7925
#
# All Scores (runs):
# [np.float64(17.5273175407455), np.float64(16.294037571042296), np.float64(17.05570240861866), np.float64(17.792520639050935), np.float64(16.920624249157793)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : shift
# Diversity : strong
# Sensors   : 15
# Mean      : 17.5624
# Std       : 0.7766
# Max       : 18.5427
#
# All Scores (runs):
# [np.float64(16.56412370120687), np.float64(16.839289215507282), np.float64(18.542721437177608), np.float64(17.571845709288475), np.float64(18.294019030893313)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : shift
# Diversity : strong
# Sensors   : 5
# Mean      : 12.2439
# Std       : 0.4551
# Max       : 12.7924
#
# All Scores (runs):
# [np.float64(12.584801114761639), np.float64(11.496054133416038), np.float64(12.016147101668166), np.float64(12.330209237282988), np.float64(12.79240054653981)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : shift
# Diversity : strong
# Sensors   : 10
# Mean      : 17.1443
# Std       : 0.9570
# Max       : 18.6471
#
# All Scores (runs):
# [np.float64(16.134341733382122), np.float64(16.849663700061356), np.float64(18.647060629543454), np.float64(16.27226503048243), np.float64(17.81813479918312)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : shift
# Diversity : strong
# Sensors   : 15
# Mean      : 18.4688
# Std       : 0.3293
# Max       : 19.0610
#
# All Scores (runs):
# [np.float64(19.06101424251734), np.float64(18.22652067138085), np.float64(18.403690638566275), np.float64(18.11666465107917), np.float64(18.53606412752027)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : shift
# Diversity : strong
# Sensors   : 5
# Mean      : 12.2260
# Std       : 0.1962
# Max       : 12.4894
#
# All Scores (runs):
# [np.float64(12.207333865003926), np.float64(12.073723545512937), np.float64(12.489401441537904), np.float64(12.398135652410812), np.float64(11.961561239988196)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : shift
# Diversity : strong
# Sensors   : 10
# Mean      : 17.4508
# Std       : 0.4803
# Max       : 18.3150
#
# All Scores (runs):
# [np.float64(18.314971150066853), np.float64(17.49726202114841), np.float64(16.90588134735742), np.float64(17.410261191482213), np.float64(17.12554694482336)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : shift
# Diversity : strong
# Sensors   : 15
# Mean      : 17.4522
# Std       : 0.6572
# Max       : 18.3962
#
# All Scores (runs):
# [np.float64(18.396158207875455), np.float64(17.25775470447721), np.float64(17.82801950406941), np.float64(16.412005454417713), np.float64(17.3671810636833)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : shift
# Diversity : strong
# Sensors   : 5
# Mean      : 12.4309
# Std       : 0.2082
# Max       : 12.6955
#
# All Scores (runs):
# [np.float64(12.695460111753011), np.float64(12.302366902357548), np.float64(12.183724897929215), np.float64(12.309096586035166), np.float64(12.664097214202213)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : shift
# Diversity : strong
# Sensors   : 10
# Mean      : 17.5061
# Std       : 0.7800
# Max       : 18.5963
#
# All Scores (runs):
# [np.float64(16.39460418510117), np.float64(17.078942818395884), np.float64(17.32078664667453), np.float64(18.59625461177715), np.float64(18.139790540925805)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : shift
# Diversity : strong
# Sensors   : 15
# Mean      : 18.7060
# Std       : 0.8052
# Max       : 19.9929
#
# All Scores (runs):
# [np.float64(19.99286722703224), np.float64(17.589095131738592), np.float64(19.05518417715965), np.float64(18.244528401257703), np.float64(18.648134946833583)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : reset
# Diversity : basic
# Sensors   : 5
# Mean      : 10.9838
# Std       : 0.6405
# Max       : 11.8441
#
# All Scores (runs):
# [np.float64(11.844064324261247), np.float64(10.484200288560986), np.float64(10.913730313046806), np.float64(11.550586047181895), np.float64(10.126431595490349)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : reset
# Diversity : basic
# Sensors   : 10
# Mean      : 14.9955
# Std       : 0.5568
# Max       : 16.0041
#
# All Scores (runs):
# [np.float64(15.109102955424348), np.float64(14.388243142139512), np.float64(14.83528000026053), np.float64(14.640796052240475), np.float64(16.004069593621143)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : reset
# Diversity : basic
# Sensors   : 15
# Mean      : 16.1460
# Std       : 0.6464
# Max       : 16.8221
#
# All Scores (runs):
# [np.float64(15.00779472979221), np.float64(16.82208606373931), np.float64(15.880344456565856), np.float64(16.485945311834257), np.float64(16.533808122681087)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : reset
# Diversity : basic
# Sensors   : 5
# Mean      : 11.7958
# Std       : 0.5583
# Max       : 12.3034
#
# All Scores (runs):
# [np.float64(12.117816695219101), np.float64(12.288903707114132), np.float64(12.30340748212254), np.float64(11.33287254589065), np.float64(10.93577449555381)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : reset
# Diversity : basic
# Sensors   : 10
# Mean      : 16.3191
# Std       : 1.1457
# Max       : 17.6517
#
# All Scores (runs):
# [np.float64(14.622417680092871), np.float64(15.97491060124887), np.float64(17.651661014175776), np.float64(17.550470039271467), np.float64(15.796014710493335)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : reset
# Diversity : basic
# Sensors   : 15
# Mean      : 16.7934
# Std       : 0.5753
# Max       : 17.5323
#
# All Scores (runs):
# [np.float64(17.532313194189356), np.float64(17.300142532894974), np.float64(16.844516431069568), np.float64(16.078800345608464), np.float64(16.211353223439584)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : reset
# Diversity : basic
# Sensors   : 5
# Mean      : 10.8209
# Std       : 0.7294
# Max       : 11.8369
#
# All Scores (runs):
# [np.float64(11.836853799839528), np.float64(11.311636550372869), np.float64(10.616561141686985), np.float64(9.67101272110568), np.float64(10.668572708994557)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : reset
# Diversity : basic
# Sensors   : 10
# Mean      : 14.9509
# Std       : 0.6523
# Max       : 15.9797
#
# All Scores (runs):
# [np.float64(14.985883827855634), np.float64(14.270592812790186), np.float64(14.24359601592456), np.float64(15.979663892410713), np.float64(15.27467317413414)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : reset
# Diversity : basic
# Sensors   : 15
# Mean      : 15.9384
# Std       : 0.5480
# Max       : 16.6366
#
# All Scores (runs):
# [np.float64(16.425502228641395), np.float64(15.938328516588507), np.float64(16.636584595991557), np.float64(15.15269931806047), np.float64(15.538776647417947)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : reset
# Diversity : basic
# Sensors   : 5
# Mean      : 11.7076
# Std       : 0.3949
# Max       : 12.1559
#
# All Scores (runs):
# [np.float64(11.982590626120293), np.float64(12.155934551429077), np.float64(11.085046792543404), np.float64(11.891982661340531), np.float64(11.422220400151884)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : reset
# Diversity : basic
# Sensors   : 10
# Mean      : 16.7727
# Std       : 0.6112
# Max       : 17.6545
#
# All Scores (runs):
# [np.float64(17.316504267472773), np.float64(16.02768501624553), np.float64(17.654545005700047), np.float64(16.49391823073266), np.float64(16.370692084079806)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : reset
# Diversity : basic
# Sensors   : 15
# Mean      : 17.3428
# Std       : 1.0640
# Max       : 19.2827
#
# All Scores (runs):
# [np.float64(16.42406257012993), np.float64(19.28272072993485), np.float64(17.656092541226524), np.float64(16.85461448979798), np.float64(16.496423191841522)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : reset
# Diversity : strong
# Sensors   : 5
# Mean      : 10.6877
# Std       : 0.7167
# Max       : 11.5428
#
# All Scores (runs):
# [np.float64(9.993191245614462), np.float64(10.891049308752763), np.float64(11.542836435437533), np.float64(11.295302136069484), np.float64(9.716172175336204)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : reset
# Diversity : strong
# Sensors   : 10
# Mean      : 14.7590
# Std       : 0.7234
# Max       : 15.8109
#
# All Scores (runs):
# [np.float64(13.588572449600294), np.float64(14.649075749902362), np.float64(15.099430511805283), np.float64(15.810901676032657), np.float64(14.647232227922089)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : reset
# Diversity : strong
# Sensors   : 15
# Mean      : 15.2018
# Std       : 0.4878
# Max       : 15.5927
#
# All Scores (runs):
# [np.float64(14.27433090302759), np.float64(15.442179107738152), np.float64(15.156392845005081), np.float64(15.54348915651585), np.float64(15.592702387887599)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : reset
# Diversity : strong
# Sensors   : 5
# Mean      : 10.9039
# Std       : 1.0029
# Max       : 12.2698
#
# All Scores (runs):
# [np.float64(9.446112071352566), np.float64(10.891386139667732), np.float64(11.67467714700306), np.float64(12.269798460773083), np.float64(10.237428368930374)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : reset
# Diversity : strong
# Sensors   : 10
# Mean      : 16.1363
# Std       : 0.2534
# Max       : 16.4507
#
# All Scores (runs):
# [np.float64(16.29016877706956), np.float64(15.695843826817141), np.float64(16.168855080615852), np.float64(16.076096817522846), np.float64(16.45065058812165)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : reset
# Diversity : strong
# Sensors   : 15
# Mean      : 16.8937
# Std       : 0.4741
# Max       : 17.6778
#
# All Scores (runs):
# [np.float64(16.636762083439166), np.float64(16.299179431162525), np.float64(17.677814123781435), np.float64(16.718139120705228), np.float64(17.136415427989494)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : reset
# Diversity : strong
# Sensors   : 5
# Mean      : 10.4231
# Std       : 0.4648
# Max       : 11.0494
#
# All Scores (runs):
# [np.float64(11.049440487367363), np.float64(10.703052128753807), np.float64(10.524350708238941), np.float64(9.705308351321618), np.float64(10.133234799702175)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : reset
# Diversity : strong
# Sensors   : 10
# Mean      : 14.6899
# Std       : 0.3183
# Max       : 15.0473
#
# All Scores (runs):
# [np.float64(14.45175746028624), np.float64(15.047261097870175), np.float64(14.230506540187273), np.float64(14.69667518448354), np.float64(15.023056479974679)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : reset
# Diversity : strong
# Sensors   : 15
# Mean      : 15.8978
# Std       : 0.5108
# Max       : 16.7510
#
# All Scores (runs):
# [np.float64(15.520600514066548), np.float64(15.93655349018044), np.float64(16.02805703552511), np.float64(16.75095445444585), np.float64(15.252999213453965)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : reset
# Diversity : strong
# Sensors   : 5
# Mean      : 11.2390
# Std       : 0.7674
# Max       : 12.5428
#
# All Scores (runs):
# [np.float64(11.299139521550504), np.float64(10.931071772993679), np.float64(12.542841910210681), np.float64(11.25357591202859), np.float64(10.168388448756337)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : reset
# Diversity : strong
# Sensors   : 10
# Mean      : 16.2230
# Std       : 0.6528
# Max       : 17.4539
#
# All Scores (runs):
# [np.float64(15.766367285286158), np.float64(16.22647129155368), np.float64(16.062203545969382), np.float64(17.453942351157245), np.float64(15.605770097485197)]
#
# --------------------------------------
# Algorithm : HYBRID
# Selection : over
# Crossover : uniform
# Mutation  : reset
# Diversity : strong
# Sensors   : 15
# Mean      : 17.5503
# Std       : 0.4289
# Max       : 18.0522
#
# All Scores (runs):
# [np.float64(17.931822332075903), np.float64(17.217666672284842), np.float64(16.914379478058535), np.float64(17.635340152519976), np.float64(18.052157682827676)]

# %%
def best_result(results):
    # =========================
    # BEST CONFIG OVERALL
    # =========================
    best = max(results, key=lambda x: x["mean"])
    print("\n===== BEST CONFIGURATION =====")

    print(f"Algorithm : {best['algorithm']}")
    print(f"Selection : {best.get('selection', '-')}")
    print(f"Crossover : {best.get('crossover', '-')}")
    print(f"Mutation  : {best.get('mutation', '-')}")
    print(f"Diversity : {best.get('diversity', '-')}")
    print(f"Init      : {best.get('init', '-')}")
    print(f"Survivor  : {best.get('survivor', '-')}")
    print(f"Sensors   : {best['sensors']}")
    print(f"\nMean Fitness : {best['mean']:.4f}")
    print(f"Max Fitness  : {best['max']:.4f}")

# %%
best_result(results)
# Out:
# ===== BEST CONFIGURATION =====
# Algorithm : HYBRID
# Selection : sus
# Crossover : uniform
# Mutation  : shift
# Diversity : basic
# Init      : heuristic
# Survivor  : rank
# Sensors   : 15
#
# Mean Fitness : 19.4697
# Max Fitness  : 19.8549

# %%
def visualize_best_solution(chromosome, grid, R):

    covered = get_coverage_map(chromosome, grid, R)

    sx = [x for x, y in chromosome]
    sy = [y for x, y in chromosome]

    cx = [x for x, y in covered]
    cy = [y for x, y in covered]

    plt.figure(figsize=(8,8))

    # coverage area
    plt.scatter(cx, cy, s=10, alpha=0.3, label="Covered Area")

    # sensors
    plt.scatter(sx, sy, c='red', s=100, label="Sensors")

    plt.title("Best Sensor Placement Solution")
    plt.xlabel("X Grid")
    plt.ylabel("Y Grid")
    plt.legend()
    plt.grid(True)

    plt.show()

# %%
import pandas as pd

# =========================
# 1. BEST CONFIGURATION OVERALL
# =========================
def get_best_config(results):
    return max(results, key=lambda x: x["mean"])


# =========================
# 2. FIND BEST RUN (BEST SEED INSIDE CONFIG)
# =========================
def get_best_run(results):
    best_run = None
    best_score = -float("inf")

    for r in results:
        if "scores" in r:
            for i, s in enumerate(r["scores"]):
                if s > best_score:
                    best_score = s
                    best_run = {
                        "score": s,
                        "config": r,
                        "run_index": i,
                        "seed": r["seeds"][i] if isinstance(r["seeds"][i], dict) else r["seeds"][i]
                    }

    return best_run


# =========================
# 3. PRINT BEST INFO
# =========================
best_config = get_best_config(results)
best_run = get_best_run(results)

print("\n" + "="*70)
print(" BEST CONFIGURATION")
print("="*70)

print(f"Algorithm : {best_config['algorithm']}")
print(f"Sensors   : {best_config['sensors']}")
print(f"Mean      : {best_config['mean']:.4f}")
print(f"Max       : {best_config['max']:.4f}")

if best_config["algorithm"] != "DE":
    print(f"Selection : {best_config['selection']}")
    print(f"Crossover : {best_config['crossover']}")
    print(f"Mutation  : {best_config['mutation']}")
    print(f"Diversity : {best_config['diversity']}")


print("\n" + "="*70)
print("🔥 BEST RUN (GLOBAL BEST SINGLE EXECUTION)")
print("="*70)

print(f"Best Score : {best_run['score']:.4f}")
print(f"Run Index  : {best_run['run_index']}")
print(f"Seed       : {best_run['seed']}")


# =========================
# 4. BEST SNAPSHOT VISUALIZATION
# =========================
config = best_run["config"]
algo = config["algorithm"]

if algo in ["GA", "HYBRID"]:
    snapshots = all_snapshots[algo]

    # find matching config snapshot
    for entry in snapshots:
        if entry["config"] == (
            config["selection"],
            config["crossover"],
            config["mutation"],
            config["diversity"],
            config["init"],
            config["survivor"],
            config["sensors"]
        ):
            run_snapshots = entry["runs"]
            break

    print("\n🔥 Showing best run evolution:")

    best_run_index = best_run["run_index"]
    for gen, sol in run_snapshots[best_run_index]:
        visualize_best_solution(sol, grid, PARAMS["radius"])


# =========================
# 5. SUMMARY TABLE
# =========================
df = pd.DataFrame(results)

print("\n" + "="*70)
print("📊 SUMMARY TABLE (Top Configurations)")
print("="*70)

display(df.sort_values("mean", ascending=False).head(10))
# Out:
# ======================================================================
#  BEST CONFIGURATION
# ======================================================================
# Algorithm : HYBRID
# Sensors   : 15
# Mean      : 19.4697
# Max       : 19.8549
# Selection : sus
# Crossover : uniform
# Mutation  : shift
# Diversity : basic
#
# ======================================================================
# 🔥 BEST RUN (GLOBAL BEST SINGLE EXECUTION)
# ======================================================================
# Best Score : 20.0237
# Run Index  : 1
# Seed       : {'run': 1, 'seed': 69898}
#
# 🔥 Showing best run evolution:
# ======================================================================
# 📊 SUMMARY TABLE (Top Configurations)
# ======================================================================
#     algorithm   selection crossover mutation diversity       init survivor  \
# 638    HYBRID         sus   uniform    shift     basic  heuristic     rank
# 446    HYBRID  tournament   uniform    shift     basic  heuristic     rank
# 443    HYBRID  tournament   uniform    shift     basic  heuristic  elitism
# 398    HYBRID  tournament  onepoint    shift     basic  heuristic     rank
# 440    HYBRID  tournament   uniform    shift     basic     random     rank
# 644    HYBRID         sus   uniform    shift    strong     random     rank
# 455    HYBRID  tournament   uniform    shift    strong  heuristic  elitism
# 494    HYBRID    roulette  onepoint    shift     basic  heuristic     rank
# 452    HYBRID  tournament   uniform    shift    strong     random     rank
# 449    HYBRID  tournament   uniform    shift    strong     random  elitism
#
#      sensors       mean       std        max  \
# 638       15  19.469698  0.320965  19.854875
# 446       15  19.317841  0.551130  19.795753
# 443       15  19.208585  0.357676  19.626061
# 398       15  19.178286  0.210347  19.494383
# 440       15  19.099267  0.587398  19.895583
# 644       15  19.088742  0.622615  19.900539
# 455       15  19.065154  0.666936  20.023730
# 494       15  19.059075  0.274134  19.395665
# 452       15  19.047329  0.612494  19.950699
# 449       15  18.926590  0.314448  19.443439
#
#                                                  seeds  \
# 638  [{'run': 0, 'seed': 94038}, {'run': 1, 'seed':...
# 446  [{'run': 0, 'seed': 68175}, {'run': 1, 'seed':...
# 443  [{'run': 0, 'seed': 77409}, {'run': 1, 'seed':...
# 398  [{'run': 0, 'seed': 23586}, {'run': 1, 'seed':...
# 440  [{'run': 0, 'seed': 95461}, {'run': 1, 'seed':...
# 644  [{'run': 0, 'seed': 17706}, {'run': 1, 'seed':...
# 455  [{'run': 0, 'seed': 21189}, {'run': 1, 'seed':...
# 494  [{'run': 0, 'seed': 93622}, {'run': 1, 'seed':...
# 452  [{'run': 0, 'seed': 19270}, {'run': 1, 'seed':...
# 449  [{'run': 0, 'seed': 12293}, {'run': 1, 'seed':...
#
#                                                 scores
# 638  [19.507514188580295, 19.771749522341903, 19.18...
# 446  [19.192444450765667, 18.309707666714594, 19.79...
# 443  [19.12346466977415, 19.225496048097153, 19.479...
# 398  [19.09625041074623, 19.352557413993097, 19.494...
# 440  [19.712075520950815, 18.755734327265074, 19.89...
# 644  [19.90053851332609, 18.793693431874082, 19.464...
# 455  [18.1169365628331, 20.023729817089308, 18.9748...
# 494  [19.36338254815447, 18.795381616431577, 18.991...
# 452  [19.4001984122093, 18.116246178726666, 18.9724...
# 449  [18.5918421332439, 18.95544568735225, 19.44343...

# %%
def plot_results(results):

    labels = []
    means = []

    for r in results:
        label = f"{r['algorithm']}"
        if r['algorithm'] != "DE": # Only add these for GA and HYBRID
            label += f"-{r['selection']}-{r['crossover']}-{r['mutation']}-{r['diversity']}"
        labels.append(label)
        means.append(r["mean"])

    plt.figure(figsize=(24,12))
    plt.barh(labels, means)

    plt.title("GA vs DE vs HYBRID Comparison")
    plt.xlabel("Mean Fitness")
    plt.grid()

    plt.show()

# %%
def plot_best_algorithms(results):

    best_ga = max([r for r in results if r["algorithm"]=="GA"], key=lambda x:x["mean"])
    best_de = max([r for r in results if r["algorithm"]=="DE"], key=lambda x:x["mean"])
    best_hybrid = max([r for r in results if r["algorithm"]=="HYBRID"], key=lambda x:x["mean"])

    labels = ["GA", "DE", "HYBRID"]
    values = [best_ga["mean"], best_de["mean"], best_hybrid["mean"]]

    plt.figure()
    plt.bar(labels, values)

    plt.title("Best Algorithm Comparison")
    plt.ylabel("Mean Fitness")

    plt.show()

# %%
def plot_sensors_vs_fitness(results):

    sensors = []
    means = []

    for r in results:
        if "sensors" in r:
            sensors.append(r["sensors"])
            means.append(r["mean"])

    plt.figure()
    plt.plot(sensors, means, marker='o')

    plt.xlabel("Number of Sensors")
    plt.ylabel("Mean Fitness")
    plt.title("Sensor Count vs Performance")

    plt.grid()
    plt.show()

# %%
plot_results(results)
plot_best_algorithms(results)
plot_sensors_vs_fitness(results)

# %%
def average_histories(histories_list):
    return np.mean(histories_list, axis=0)
def plot_convergence(ga_hist, de_hist, hybrid_hist=None):

    plt.figure(figsize=(10,6))

    plt.plot(ga_hist, label="GA", linewidth=2)

    plt.plot(de_hist, label="DE", linewidth=2)

    if hybrid_hist is not None:
        plt.plot(hybrid_hist, label="Hybrid (GA+DE)", linewidth=2)

    plt.xlabel("Generation")
    plt.ylabel("Best Fitness")
    plt.title("Convergence Comparison")
    plt.legend()
    plt.grid(True)

    plt.show()

# %%
ga_avg = average_histories(histories["GA"])
de_avg = average_histories(histories["DE"])
hybrid_avg = average_histories(histories["HYBRID"])

plot_convergence(ga_avg, de_avg, hybrid_avg)

# %%
def visualize_final_solution(chromosome, grid, R):

    n, m = grid.shape

    coverage_count = np.zeros((n, m))

    for (si, sj) in chromosome:
        for i in range(max(0, si-R), min(n, si+R+1)):
            for j in range(max(0, sj-R), min(m, sj+R+1)):

                if np.linalg.norm([si-i, sj-j]) <= R:
                    coverage_count[i][j] += 1

    sx = [x for x, y in chromosome]
    sy = [y for x, y in chromosome]

    plt.figure(figsize=(8,8))

    # background: coverage intensity
    plt.imshow(coverage_count, cmap="Blues", alpha=0.6, origin="lower")

    # sensors
    plt.scatter(sx, sy, c='red', s=120, label="Sensors")

    plt.title("Final Sensor Placement with Coverage Heatmap")
    plt.xlabel("X Grid")
    plt.ylabel("Y Grid")
    plt.legend()
    plt.grid(False)

    plt.show()

# %%
# The original 'snapshots' variable was overwritten by `all_snapshots[algo]` in a previous cell,
# causing the ValueError because it became a list of dictionaries, not (gen, sol) tuples.
# We need to retrieve the snapshots for the globally best run identified by `best_run`.

# Get the configuration details of the best run
current_config = best_run["config"]
current_algo = current_config["algorithm"]

# Find the snapshots container for the algorithm of the best run
# This is a list of dictionaries, where each dict contains a config and a list of runs' snapshots
snapshots_for_algo = all_snapshots[current_algo]

# Reconstruct the config tuple for the best run to match the format stored in all_snapshots
best_config_tuple = (
    current_config["selection"],
    current_config["crossover"],
    current_config["mutation"],
    current_config["diversity"],
    current_config["init"],
    current_config["survivor"],
    current_config["sensors"]
)

# Iterate through the snapshots_for_algo to find the specific config that matches best_run
run_snapshots_collection_for_config = None
for entry in snapshots_for_algo:
    if entry["config"] == best_config_tuple:
        # 'runs' contains a list of snapshot lists, one for each run of this specific config
        run_snapshots_collection_for_config = entry["runs"]
        break

# If run_snapshots_collection_for_config was found, get the snapshots for the specific best run index
if run_snapshots_collection_for_config is not None:
    best_run_index = best_run["run_index"]
    # This 'correct_snapshots' variable now holds the list of (gen, sol) tuples
    correct_snapshots = run_snapshots_collection_for_config[best_run_index]

    for gen, sol in correct_snapshots:
        print(f"\nGeneration {gen}")
        visualize_final_solution(sol, grid, PARAMS["radius"])
else:
    print("Could not find snapshots for the best run's configuration.")
# Out:
# Generation 0
# Generation 15
# Generation 29

# %%
def plot_sensor_distribution(chromosome, grid):

    sx = [x for x, y in chromosome]
    sy = [y for x, y in chromosome]

    plt.figure(figsize=(7,7))

    # optional: background density
    plt.imshow(grid, cmap="Blues", alpha=0.5)

    plt.scatter(sx, sy, c='red', s=120, label="Sensors")

    plt.title("Sensor Distribution Map")
    plt.xlabel("X Grid")
    plt.ylabel("Y Grid")
    plt.legend()
    plt.grid(True)

    plt.show()

# %%
def plot_coverage_heatmap(chromosome, grid, R):

    n, m = grid.shape
    coverage_count = np.zeros((n, m))

    for (si, sj) in chromosome:
        for i in range(max(0, si-R), min(n, si+R+1)):
            for j in range(max(0, sj-R), min(m, sj+R+1)):

                if np.linalg.norm([si-i, sj-j]) <= R:
                    coverage_count[i][j] += 1

    plt.figure(figsize=(8,6))

    plt.imshow(coverage_count, cmap="hot", origin="lower")

    plt.colorbar(label="Coverage Strength (Sensor Overlap)")

    plt.title("Coverage Heatmap")
    plt.xlabel("X Grid")
    plt.ylabel("Y Grid")

    plt.show()

# %%
def plot_uncovered_heatmap(chromosome, grid, R):

    n, m = grid.shape
    covered = set()

    for (si, sj) in chromosome:
        for i in range(max(0, si-R), min(n, si+R+1)):
            for j in range(max(0, sj-R), min(m, sj+R+1)):

                if np.linalg.norm([si-i, sj-j]) <= R:
                    covered.add((i, j))

    uncovered = np.zeros((n, m))

    for i in range(n):
        for j in range(m):
            if (i, j) not in covered:
                uncovered[i][j] = 1

    plt.figure(figsize=(8,6))

    plt.imshow(uncovered, cmap="Reds", origin="lower")

    plt.title("Uncovered Areas Heatmap")
    plt.xlabel("X Grid")
    plt.ylabel("Y Grid")

    plt.show()

# %%
plot_sensor_distribution(hybrid_best_solution, grid)
plot_coverage_heatmap(hybrid_best_solution, grid, PARAMS["radius"])
plot_uncovered_heatmap(hybrid_best_solution, grid, PARAMS["radius"])
visualize_final_solution(hybrid_best_solution, grid, PARAMS["radius"])

# %%
import joblib

# SAVE
joblib.dump(results, "results.pkl")
joblib.dump(histories, "histories.pkl")
joblib.dump(all_snapshots, "snapshots.pkl")
joblib.dump(all_diversity, "diversity.pkl")

print("Saved successfully!")
# Out:
# Saved successfully!

# %%
import pandas as pd

df = pd.DataFrame(results)
df.to_csv("results_summary.csv", index=False)

print("CSV saved!")
# Out:
# CSV saved!
